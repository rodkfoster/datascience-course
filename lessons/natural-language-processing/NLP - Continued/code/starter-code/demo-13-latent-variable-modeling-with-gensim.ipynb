# %% [markdown]
# # Demo 13 Latent Variable Modeling with `gensim`

# %% [markdown]
# `gensim` (http://radimrehurek.com/gensim) is a library of language processing tools focused on latent variable models of text.

# %%
import os
from os import path
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from gensim import matutils
from gensim.models.ldamodel import LdaModel
from gensim.models.word2vec import Word2Vec

pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %matplotlib inline
plt.style.use('ggplot')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# The data is about sentiments on Amazon reviews.

# %%
reviews = []
sentiments = []

with open('amazon-reviews.txt') as f:
    for line in f.readlines():
        line = line.strip('\n')
        review, sentiment = line.split('\t')
        sentiment = np.nan if sentiment == '' else int(sentiment)

        reviews.append(review.lower())
        sentiments.append(sentiment)

df = pd.DataFrame({'review': reviews, 'sentiment': sentiments})

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  i try not to adjust the volume setting to avoi...        NaN
# 1  so there is no way for me to plug it in here i...        0.0
# 2                        good case, excellent value.        1.0
# 3        i thought motorola made reliable products!.        NaN
# 4                         battery for motorola razr.        NaN

# %%
df.dropna(inplace = True) # Let's drop the NaN

# %%
df.head()
# Out:
#                                                review  sentiment
# 1   so there is no way for me to plug it in here i...        0.0
# 2                         good case, excellent value.        1.0
# 5                              great for the jawbone.        1.0
# 10  tied to charger for conversations lasting more...        0.0
# 11                                  the mic is great.        1.0

# %% [markdown]
# ## LDA with `gensim`

# %% [markdown]
# ### Let's first translate a set of documents (articles) into a matrix representation with a row per document and a column per feature (word or n-gram)

# %%
vect = CountVectorizer(stop_words = 'english')

# %%
documents = vect.fit_transform(df.review)

# %%
# Let's now build a mapping of numerical ID to word

id2word = dict(enumerate(vect.get_feature_names()))

# %%
id2word
# Out:
# {0: '10',
#  1: '100',
#  2: '11',
#  3: '12',
#  4: '13',
#  5: '15',
#  6: '15g',
#  7: '18',
#  8: '20',
#  9: '2000',
#  10: '2005',
#  11: '2160',
#  12: '24',
#  13: '2mp',
#  14: '325',
#  15: '350',
#  16: '375',
#  17: '3o',
#  18: '42',
#  19: '44',
#  20: '45',
#  21: '4s',
#  22: '50',
#  23: '5020',
#  24: '510',
#  25: '5320',
#  26: '680',
#  27: '700w',
#  28: '8125',
#  29: '8525',
#  30: '8530',
#  31: 'abhor',
#  32: 'ability',
#  33: 'able',
#  34: 'abound',
#  35: 'absolutel',
#  36: 'absolutely',
#  37: 'ac',
#  38: 'accept',
#  39: 'acceptable',
#  40: 'access',
#  41: 'accessable',
#  42: 'accessing',
#  43: 'accessory',
#  44: 'accessoryone',
#  45: 'accidentally',
#  46: 'accompanied',
#  47: 'according',
#  48: 'activate',
#  49: 'activated',
#  50: 'activesync',
#  51: 'actually',
#  52: 'ad',
#  53: 'adapter',
#  54: 'adapters',
#  55: 'add',
#  56: 'addition',
#  57: 'additional',
#  58: 'address',
#  59: 'adhesive',
#  60: 'adorable',
#  61: 'advertised',
#  62: 'advise',
#  63: 'aggravating',
#  64: 'ago',
#  65: 'alarm',
#  66: 'allot',
#  67: 'allow',
#  68: 'allowing',
#  69: 'allows',
#  70: 'alot',
#  71: 'aluminum',
#  72: 'amazed',
#  73: 'amazing',
#  74: 'amazon',
#  75: 'amp',
#  76: 'ample',
#  77: 'angeles',
#  78: 'angle',
#  79: 'answer',
#  80: 'ant',
#  81: 'antena',
#  82: 'anti',
#  83: 'apart',
#  84: 'apartment',
#  85: 'apparently',
#  86: 'appealing',
#  87: 'appearance',
#  88: 'appears',
#  89: 'applifies',
#  90: 'appointments',
#  91: 'area',
#  92: 'arguing',
#  93: 'armband',
#  94: 'arrival',
#  95: 'arrived',
#  96: 'asia',
#  97: 'ask',
#  98: 'aspect',
#  99: 'assumed',
#  100: 'atleast',
#  101: 'att',
#  102: 'attacked',
#  103: 'attractive',
#  104: 'audio',
#  105: 'authentic',
#  106: 'auto',
#  107: 'available',
#  108: 'average',
#  109: 'avoid',
#  110: 'avoiding',
#  111: 'away',
#  112: 'awesome',
#  113: 'awful',
#  114: 'awkward',
#  115: 'awsome',
#  116: 'background',
#  117: 'backlight',
#  118: 'bad',
#  119: 'balance',
#  120: 'bar',
#  121: 'barely',
#  122: 'bargain',
#  123: 'bars',
#  124: 'basement',
#  125: 'basic',
#  126: 'basically',
#  127: 'batteries',
#  128: 'battery',
#  129: 'beat',
#  130: 'beats',
#  131: 'beautiful',
#  132: 'bed',
#  133: 'beep',
#  134: 'beeping',
#  135: 'behing',
#  136: 'believe',
#  137: 'bells',
#  138: 'belt',
#  139: 'bend',
#  140: 'best',
#  141: 'better',
#  142: 'beware',
#  143: 'big',
#  144: 'biggest',
#  145: 'bills',
#  146: 'bit',
#  147: 'bitpim',
#  148: 'black',
#  149: 'blackberry',
#  150: 'blacktop',
#  151: 'bland',
#  152: 'blew',
#  153: 'blue',
#  154: 'blueant',
#  155: 'bluetoooth',
#  156: 'bluetooth',
#  157: 'bluetooths',
#  158: 'bmw',
#  159: 'book',
#  160: 'booking',
#  161: 'boost',
#  162: 'boot',
#  163: 'bose',
#  164: 'bother',
#  165: 'bottowm',
#  166: 'bought',
#  167: 'bougth',
#  168: 'boy',
#  169: 'brand',
#  170: 'break',
#  171: 'breakage',
#  172: 'breaking',
#  173: 'breaks',
#  174: 'brilliant',
#  175: 'broke',
#  176: 'broken',
#  177: 'browser',
#  178: 'browsing',
#  179: 'bt',
#  180: 'bt250v',
#  181: 'bt50',
#  182: 'bubbling',
#  183: 'bucks',
#  184: 'buds',
#  185: 'build',
#  186: 'built',
#  187: 'bulky',
#  188: 'bumpers',
#  189: 'button',
#  190: 'buttons',
#  191: 'buy',
#  192: 'buyer',
#  193: 'buyers',
#  194: 'buying',
#  195: 'buyit',
#  196: 'buzzing',
#  197: 'ca',
#  198: 'cable',
#  199: 'cables',
#  200: 'calendar',
#  201: 'called',
#  202: 'calls',
#  203: 'came',
#  204: 'camera',
#  205: 'canal',
#  206: 'cancellation',
#  207: 'cancelling',
#  208: 'capability',
#  209: 'capacity',
#  210: 'car',
#  211: 'card',
#  212: 'care',
#  213: 'careful',
#  214: 'carried',
#  215: 'carriers',
#  216: 'carries',
#  217: 'carry',
#  218: 'case',
#  219: 'cases',
#  220: 'casing',
#  221: 'cassette',
#  222: 'cat',
#  223: 'catching',
#  224: 'caused',
#  225: 'causing',
#  226: 'cbr',
#  227: 'cds',
#  228: 'cell',
#  229: 'cellphone',
#  230: 'cellphones',
#  231: 'cellular',
#  232: 'cent',
#  233: 'center',
#  234: 'certain',
#  235: 'certainly',
#  236: 'changing',
#  237: 'channel',
#  238: 'charge',
#  239: 'charged',
#  240: 'charger',
#  241: 'chargers',
#  242: 'charges',
#  243: 'charging',
#  244: 'charm',
#  245: 'cheap',
#  246: 'cheaper',
#  247: 'cheaply',
#  248: 'cheapy',
#  249: 'check',
#  250: 'checked',
#  251: 'child',
#  252: 'china',
#  253: 'chinese',
#  254: 'choice',
#  255: 'choices',
#  256: 'christmas',
#  257: 'cingulair',
#  258: 'cingular',
#  259: 'clarity',
#  260: 'classy',
#  261: 'clear',
#  262: 'clearer',
#  263: 'clearly',
#  264: 'clever',
#  265: 'clicks',
#  266: 'clip',
#  267: 'clipping',
#  268: 'clips',
#  269: 'clock',
#  270: 'colleague',
#  271: 'color',
#  272: 'colored',
#  273: 'colors',
#  274: 'combination',
#  275: 'come',
#  276: 'comes',
#  277: 'comfort',
#  278: 'comfortable',
#  279: 'comfortably',
#  280: 'comfortible',
#  281: 'coming',
#  282: 'comments',
#  283: 'commercials',
#  284: 'communicate',
#  285: 'communication',
#  286: 'communications',
#  287: 'commuter',
#  288: 'company',
#  289: 'comparably',
#  290: 'compared',
#  291: 'compete',
#  292: 'competitors',
#  293: 'complain',
#  294: 'complained',
#  295: 'complaint',
#  296: 'complaints',
#  297: 'completely',
#  298: 'compliments',
#  299: 'compromise',
#  300: 'computer',
#  301: 'concrete',
#  302: 'conditions',
#  303: 'confortable',
#  304: 'confusing',
#  305: 'connect',
#  306: 'connected',
#  307: 'connecting',
#  308: 'connection',
#  309: 'constantly',
#  310: 'constructed',
#  311: 'construction',
#  312: 'consumer',
#  313: 'contact',
#  314: 'contacted',
#  315: 'contacting',
#  316: 'contacts',
#  317: 'continue',
#  318: 'continues',
#  319: 'contract',
#  320: 'control',
#  321: 'controls',
#  322: 'contstruct',
#  323: 'convenient',
#  324: 'conversation',
#  325: 'conversations',
#  326: 'converter',
#  327: 'cool',
#  328: 'copier',
#  329: 'copy',
#  330: 'corded',
#  331: 'correctly',
#  332: 'cost',
#  333: 'costs',
#  334: 'couldn',
#  335: 'counter',
#  336: 'counterfeit',
#  337: 'couple',
#  338: 'coupon',
#  339: 'course',
#  340: 'cover',
#  341: 'coverage',
#  342: 'covered',
#  343: 'crack',
#  344: 'cracked',
#  345: 'cradle',
#  346: 'cradles',
#  347: 'crap',
#  348: 'crappy',
#  349: 'crashed',
#  350: 'crawl',
#  351: 'creaks',
#  352: 'crisp',
#  353: 'cumbersome',
#  354: 'current',
#  355: 'currently',
#  356: 'curve',
#  357: 'customer',
#  358: 'cut',
#  359: 'cute',
#  360: 'cutouts',
#  361: 'cuts',
#  362: 'd807',
#  363: 'damage',
#  364: 'darn',
#  365: 'data',
#  366: 'date',
#  367: 'day',
#  368: 'days',
#  369: 'dead',
#  370: 'deaf',
#  371: 'deal',
#  372: 'decade',
#  373: 'decent',
#  374: 'decision',
#  375: 'defeats',
#  376: 'defect',
#  377: 'defective',
#  378: 'deffinitely',
#  379: 'definitely',
#  380: 'definitly',
#  381: 'delay',
#  382: 'delivery',
#  383: 'described',
#  384: 'description',
#  385: 'design',
#  386: 'designed',
#  387: 'designs',
#  388: 'despite',
#  389: 'destination',
#  390: 'destroying',
#  391: 'detachable',
#  392: 'detailed',
#  393: 'development',
#  394: 'device',
#  395: 'devices',
#  396: 'dialing',
#  397: 'did',
#  398: 'didn',
#  399: 'died',
#  400: 'dieing',
#  401: 'different',
#  402: 'difficult',
#  403: 'directed',
#  404: 'directions',
#  405: 'directly',
#  406: 'dirty',
#  407: 'disapoinment',
#  408: 'disapointing',
#  409: 'disappoint',
#  410: 'disappointed',
#  411: 'disappointing',
#  412: 'disappointment',
#  413: 'discarded',
#  414: 'discomfort',
#  415: 'disconnected',
#  416: 'discount',
#  417: 'disgusting',
#  418: 'display',
#  419: 'displeased',
#  420: 'disposable',
#  421: 'dissapointed',
#  422: 'dissapointing',
#  423: 'distorted',
#  424: 'distracting',
#  425: 'dit',
#  426: 'division',
#  427: 'dna',
#  428: 'docking',
#  429: 'does',
#  430: 'doesn',
#  431: 'doing',
#  432: 'dollar',
#  433: 'don',
#  434: 'dont',
#  435: 'double',
#  436: 'download',
#  437: 'downloading',
#  438: 'dozen',
#  439: 'dozens',
#  440: 'drain',
#  441: 'drained',
#  442: 'drains',
#  443: 'drawback',
#  444: 'driving',
#  445: 'drivng',
#  446: 'droid',
#  447: 'drop',
#  448: 'dropped',
#  449: 'dropping',
#  450: 'drops',
#  451: 'dual',
#  452: 'durable',
#  453: 'dustpan',
#  454: 'dying',
#  455: 'e2',
#  456: 'e715',
#  457: 'ear',
#  458: 'earbud',
#  459: 'earbuds',
#  460: 'earbugs',
#  461: 'eargels',
#  462: 'earlier',
#  463: 'earpad',
#  464: 'earphone',
#  465: 'earphones',
#  466: 'earpiece',
#  467: 'earpieces',
#  468: 'ears',
#  469: 'earset',
#  470: 'ease',
#  471: 'easier',
#  472: 'easily',
#  473: 'easy',
#  474: 'echo',
#  475: 'edge',
#  476: 'effect',
#  477: 'effective',
#  478: 'effects',
#  479: 'effort',
#  480: 'electronics',
#  481: 'elegant',
#  482: 'embarassing',
#  483: 'embarrassing',
#  484: 'embedded',
#  485: 'encourage',
#  486: 'end',
#  487: 'ended',
#  488: 'ends',
#  489: 'engineered',
#  490: 'enjoy',
#  491: 'enter',
#  492: 'entertainment',
#  493: 'entire',
#  494: 'env',
#  495: 'equipment',
#  496: 'era',
#  497: 'ergonomic',
#  498: 'ericson',
#  499: 'ericsson',
#  500: 'especially',
#  501: 'essentially',
#  502: 'europe',
#  503: 'eventually',
#  504: 'everyday',
#  505: 'exactly',
#  506: 'exceeds',
#  507: 'excelent',
#  508: 'excellent',
#  509: 'excels',
#  510: 'exceptional',
#  511: 'excessive',
#  512: 'exchange',
#  513: 'exchanged',
#  514: 'excited',
#  515: 'exclaim',
#  516: 'excrutiatingly',
#  517: 'exercise',
#  518: 'existing',
#  519: 'expect',
#  520: 'expectations',
#  521: 'expected',
#  522: 'expensive',
#  523: 'experience',
#  524: 'experienced',
#  525: 'explain',
#  526: 'extended',
#  527: 'exterior',
#  528: 'external',
#  529: 'extra',
#  530: 'extremely',
#  531: 'eye',
#  532: 'fabulous',
#  533: 'face',
#  534: 'faceplates',
#  535: 'fact',
#  536: 'factor',
#  537: 'failed',
#  538: 'fails',
#  539: 'fairly',
#  540: 'fall',
#  541: 'falling',
#  542: 'falls',
#  543: 'family',
#  544: 'fantastic',
#  545: 'far',
#  546: 'fast',
#  547: 'faster',
#  548: 'father',
#  549: 'favorite',
#  550: 'feature',
#  551: 'features',
#  552: 'fee',
#  553: 'feel',
#  554: 'feels',
#  555: 'feet',
#  556: 'felt',
#  557: 'fi',
#  558: 'figure',
#  559: 'file',
#  560: 'finally',
#  561: 'finds',
#  562: 'fine',
#  563: 'fingers',
#  564: 'finished',
#  565: 'fit',
#  566: 'fits',
#  567: 'fixes',
#  568: 'flash',
#  569: 'flaw',
#  570: 'flawed',
#  571: 'flawless',
#  572: 'flawlessly',
#  573: 'flaws',
#  574: 'flimsy',
#  575: 'flip',
#  576: 'flipphones',
#  577: 'fliptop',
#  578: 'floor',
#  579: 'floppy',
#  580: 'flops',
#  581: 'flush',
#  582: 'fm',
#  583: 'followed',
#  584: 'fond',
#  585: 'fooled',
#  586: 'forced',
#  587: 'forever',
#  588: 'forgeries',
#  589: 'forget',
#  590: 'forgot',
#  591: 'form',
#  592: 'fourth',
#  593: 'fraction',
#  594: 'free',
#  595: 'freedom',
#  596: 'freeway',
#  597: 'freezes',
#  598: 'frequently4',
#  599: 'frequentyly',
#  600: 'friendly',
#  601: 'friends',
#  602: 'frog',
#  603: 'frustration',
#  604: 'fry',
#  605: 'ft',
#  606: 'fulfills',
#  607: 'fully',
#  608: 'fun',
#  609: 'function',
#  610: 'functional',
#  611: 'functionality',
#  612: 'functions',
#  613: 'funny',
#  614: 'gadget',
#  615: 'gadgets',
#  616: 'games',
#  617: 'garbage',
#  618: 'garbled',
#  619: 'gave',
#  620: 'geeky',
#  621: 'gels',
#  622: 'generally',
#  623: 'gentle',
#  624: 'genuine',
#  625: 'gets',
#  626: 'getting',
#  627: 'gimmick',
#  628: 'girl',
#  629: 'given',
#  630: 'giving',
#  631: 'glad',
#  632: 'glare',
#  633: 'glasses',
#  634: 'glove',
#  635: 'glued',
#  636: 'goes',
#  637: 'going',
#  638: 'gonna',
#  639: 'good',
#  640: 'good7',
#  641: 'gosh',
#  642: 'got',
#  643: 'gotten',
#  644: 'graphics',
#  645: 'great',
#  646: 'greater',
#  647: 'grey',
#  648: 'grip',
#  649: 'grtting',
#  650: 'guess',
#  651: 'gx2',
#  652: 'h500',
#  653: 'hair',
#  654: 'hand',
#  655: 'handheld',
#  656: 'hands',
#  657: 'handset',
#  658: 'handsfree',
#  659: 'handy',
#  660: 'happened',
#  661: 'happening',
#  662: 'happens',
#  663: 'happier',
#  664: 'happy',
#  665: 'hard',
#  666: 'hardly',
#  667: 'hat',
#  668: 'hate',
#  669: 'hated',
#  670: 'haul',
#  671: 'haven',
#  672: 'having',
#  673: 'headbands',
#  674: 'headphones',
#  675: 'headset',
#  676: 'headsets',
#  677: 'hear',
#  678: 'hearing',
#  679: 'heavy',
#  680: 'help',
#  681: 'helpful',
#  682: 'hey',
#  683: 'high',
#  684: 'highest',
#  685: 'highly',
#  686: 'highy',
#  687: 'hinge',
#  688: 'hit',
#  689: 'hitch',
#  690: 'hold',
#  691: 'holder',
#  692: 'holding',
#  693: 'holds',
#  694: 'holster',
#  695: 'home',
#  696: 'hook',
#  697: 'hoped',
#  698: 'hoping',
#  699: 'horrible',
#  700: 'hot',
#  701: 'hour',
#  702: 'hours',
#  703: 'hoursthe',
#  704: 'house',
#  705: 'hs850',
#  706: 'huge',
#  707: 'humans',
#  708: 'humming',
#  709: 'hurt',
#  710: 'hybrid',
#  711: 'hype',
#  712: 'iam',
#  713: 'idea',
#  714: 'ideal',
#  715: 'igo',
#  716: 'ill',
#  717: 'im',
#  718: 'imac',
#  719: 'images',
#  720: 'imagine',
#  721: 'immediately',
#  722: 'important',
#  723: 'impossible',
#  724: 'impressed',
#  725: 'impressive',
#  726: 'improper',
#  727: 'improve',
#  728: 'improvement',
#  729: 'inches',
#  730: 'included',
#  731: 'incoming',
#  732: 'inconspicuous',
#  733: 'increase',
#  734: 'incrediable',
#  735: 'incredible',
#  736: 'incredibly',
#  737: 'indoors',
#  738: 'industrial',
#  739: 'inexcusable',
#  740: 'inexpensive',
#  741: 'infatuated',
#  742: 'inform',
#  743: 'infra',
#  744: 'infuriating',
#  745: 'insert',
#  746: 'inside',
#  747: 'install',
#  748: 'installed',
#  749: 'instance',
#  750: 'instead',
#  751: 'instruction',
#  752: 'instructions',
#  753: 'integrated',
#  754: 'intended',
#  755: 'interested',
#  756: 'interface',
#  757: 'intermittently',
#  758: 'internet',
#  759: 'invented',
#  760: 'investment',
#  761: 'iphone',
#  762: 'ipod',
#  763: 'ipods',
#  764: 'ir',
#  765: 'irda',
#  766: 'iriver',
#  767: 'isn',
#  768: 'issues',
#  769: 'item',
#  770: 'items',
#  771: 'jabra',
#  772: 'jabra350',
#  773: 'jack',
#  774: 'jawbone',
#  775: 'jerks',
#  776: 'jiggle',
#  777: 'job',
#  778: 'joke',
#  779: 'joy',
#  780: 'juice',
#  781: 'junk',
#  782: 'just',
#  783: 'jx',
#  784: 'keen',
#  785: 'keeping',
#  786: 'keeps',
#  787: 'kept',
#  788: 'key',
#  789: 'keyboard',
#  790: 'keypad',
#  791: 'keypads',
#  792: 'keys',
#  793: 'killer',
#  794: 'kind',
#  795: 'kindle',
#  796: 'kitchen',
#  797: 'kits',
#  798: 'knock',
#  799: 'know',
#  800: 'knows',
#  801: 'krussel',
#  802: 'l7c',
#  803: 'lacking',
#  804: 'land',
#  805: 'lap',
#  806: 'laptop',
#  807: 'large',
#  808: 'lasted',
#  809: 'lasting',
#  810: 'lasts',
#  811: 'latch',
#  812: 'lately',
#  813: 'later',
#  814: 'latest',
#  815: 'laughing',
#  816: 'leaf',
#  817: 'leaks',
#  818: 'learned',
#  819: 'leather',
#  820: 'left',
#  821: 'lense',
#  822: 'leopard',
#  823: 'lesson',
#  824: 'let',
#  825: 'letting',
#  826: 'lg',
#  827: 'life',
#  828: 'light',
#  829: 'lightly',
#  830: 'lights',
#  831: 'lightweight',
#  832: 'like',
#  833: 'liked',
#  834: 'likes',
#  835: 'line',
#  836: 'linked',
#  837: 'linking',
#  838: 'linksys',
#  839: 'listener',
#  840: 'listening',
#  841: 'lit',
#  842: 'literally',
#  843: 'little',
#  844: 'living',
#  845: 'll',
#  846: 'loads',
#  847: 'lock',
#  848: 'locked',
#  849: 'locks',
#  850: 'logitech',
#  851: 'long',
#  852: 'longer',
#  853: 'look',
#  854: 'looking',
#  855: 'looks',
#  856: 'loop',
#  857: 'loops',
#  858: 'loose',
#  859: 'looses',
#  860: 'los',
#  861: 'lose',
#  862: 'lost',
#  863: 'lot',
#  864: 'lots',
#  865: 'loud',
#  866: 'louder',
#  867: 'loudest',
#  868: 'loudspeaker',
#  869: 'lousy',
#  870: 'love',
#  871: 'loved',
#  872: 'loves',
#  873: 'low',
#  874: 'luck',
#  875: 'machine',
#  876: 'magical',
#  877: 'magnetic',
#  878: 'mail',
#  879: 'mainly',
#  880: 'maintain',
#  881: 'maintains',
#  882: 'major',
#  883: 'majority',
#  884: 'make',
#  885: 'makes',
#  886: 'making',
#  887: 'managed',
#  888: 'management',
#  889: 'manual',
#  890: 'manufacturer',
#  891: 'mark',
#  892: 'market',
#  893: 'match',
#  894: 'material',
#  895: 'max',
#  896: 'means',
#  897: 'mechanism',
#  898: 'media',
#  899: 'mediocre',
#  900: 'mega',
#  901: 'megapixels',
#  902: 'memory',
#  903: 'mention',
#  904: 'mentioned',
#  905: 'menus',
#  906: 'mere',
#  907: 'mess',
#  908: 'message',
#  909: 'messages',
#  910: 'messaging',
#  911: 'messes',
#  912: 'metal',
#  913: 'metro',
#  914: 'mic',
#  915: 'microphone',
#  916: 'microsoft',
#  917: 'mind',
#  918: 'mini',
#  919: 'mins',
#  920: 'minute',
#  921: 'minutes',
#  922: 'misleading',
#  923: 'missed',
#  924: 'mistake',
#  925: 'mobile',
#  926: 'mode',
#  927: 'model',
#  928: 'modest',
#  929: 'money',
#  930: 'monkeys',
#  931: 'month',
#  932: 'months',
#  933: 'morning',
#  934: 'mother',
#  935: 'moto',
#  936: 'motor',
#  937: 'motorola',
#  938: 'motorolas',
#  939: 'moving',
#  940: 'mp3',
#  941: 'mp3s',
#  942: 'muddy',
#  943: 'muffled',
#  944: 'multiple',
#  945: 'music',
#  946: 'mute',
#  947: 'nano',
#  948: 'navigate',
#  949: 'near',
#  950: 'nearly',
#  951: 'neat',
#  952: 'need',
#  953: 'needed',
#  954: 'needless',
#  955: 'needs',
#  956: 'negatively',
#  957: 'network',
#  958: 'new',
#  959: 'ngage',
#  960: 'nice',
#  961: 'nicely',
#  962: 'nicer',
#  963: 'night',
#  964: 'nightmare',
#  965: 'noise',
#  966: 'noises',
#  967: 'nokia',
#  968: 'normal',
#  969: 'normally',
#  970: 'note',
#  971: 'noted',
#  972: 'notice',
#  973: 'noticed',
#  974: 'number',
#  975: 'numbers',
#  976: 'numerous',
#  977: 'nyc',
#  978: 'obviously',
#  979: 'occupied',
#  980: 'odd',
#  981: 'oem',
#  982: 'offering',
#  983: 'offers',
#  984: 'official',
#  985: 'oh',
#  986: 'ok',
#  987: 'old',
#  988: 'ones',
#  989: 'online',
#  990: 'oozes',
#  991: 'open',
#  992: 'opens',
#  993: 'operate',
#  994: 'operates',
#  995: 'optimal',
#  996: 'option',
#  997: 'options',
#  998: 'order',
#  999: 'ordered',
#  ...}

# %% [markdown]
# ### We want to learn which columns are correlated (i.e., likely to come from the same topic).  This is the word distribution.  We can also determine what topics are in each document, the topic distribution.

# %%
# First we convert our word-matrix into gensim's format

corpus = matutils.Sparse2Corpus(documents, documents_columns = False)

# %% [markdown]
# (Check https://radimrehurek.com/gensim/matutils as needed)

# %% [markdown]
# (Check https://radimrehurek.com/gensim/models/ldamodel as needed)

# %%
# Then we fit an LDA model

lda = LdaModel(corpus = corpus, num_topics = 25, id2word = id2word, passes = 10)

# %% [markdown]
# In this model, we need to explicitly specify the number of topic we want the model to uncover.  This is a critical parameter, but there isn't much guidance on how to choose it.  Try to use domain expertise where possible.

# %% [markdown]
# ### Goodness of fit

# %% [markdown]
# Now we need to assess the goodness of fit for our model.  Like other unsupervised learning techniques, our validation techniques are mostly about interpretation.
#
# Use the following questions to guide you:
# - Did we learn reasonable topics?
# - Do the words that make up a topic make sense?
# - Is this topic helpful towards our goal?

# %%
lda.print_topics()
# Out:
# [(9,
#   '0.052*"phone" + 0.012*"worked" + 0.012*"ear" + 0.012*"color" + 0.012*"job" + 0.009*"nice" + 0.008*"battery" + 0.008*"don" + 0.008*"great" + 0.008*"impressed"'),
#  (8,
#   '0.178*"great" + 0.066*"phone" + 0.051*"works" + 0.030*"love" + 0.022*"waste" + 0.018*"product" + 0.017*"time" + 0.015*"ve" + 0.014*"device" + 0.012*"money"'),
#  (23,
#   '0.037*"nice" + 0.033*"phone" + 0.018*"work" + 0.015*"did" + 0.012*"weeks" + 0.012*"better" + 0.012*"problem" + 0.012*"mistake" + 0.011*"good" + 0.010*"make"'),
#  (17,
#   '0.021*"charger" + 0.018*"great" + 0.015*"works" + 0.013*"quality" + 0.012*"use" + 0.012*"phone" + 0.012*"people" + 0.011*"nice" + 0.008*"seriously" + 0.008*"case"'),
#  (15,
#   '0.028*"ve" + 0.027*"phone" + 0.027*"far" + 0.020*"good" + 0.017*"does" + 0.016*"sound" + 0.012*"quality" + 0.012*"like" + 0.012*"best" + 0.009*"ear"'),
#  (6,
#   '0.038*"buy" + 0.027*"don" + 0.020*"product" + 0.017*"phone" + 0.016*"makes" + 0.012*"calls" + 0.012*"easier" + 0.011*"working" + 0.011*"hold" + 0.010*"unreliable"'),
#  (1,
#   '0.022*"bad" + 0.020*"phone" + 0.020*"case" + 0.018*"really" + 0.018*"headset" + 0.017*"good" + 0.016*"right" + 0.013*"recommend" + 0.012*"battery" + 0.012*"use"'),
#  (16,
#   '0.025*"phone" + 0.025*"best" + 0.020*"works" + 0.015*"charger" + 0.015*"right" + 0.015*"market" + 0.015*"low" + 0.015*"item" + 0.010*"sure" + 0.010*"pictures"'),
#  (19,
#   '0.034*"battery" + 0.025*"phone" + 0.022*"charge" + 0.020*"headsets" + 0.018*"good" + 0.016*"product" + 0.015*"buy" + 0.010*"year" + 0.010*"went" + 0.010*"helpful"'),
#  (13,
#   '0.023*"ear" + 0.019*"phone" + 0.013*"used" + 0.012*"overall" + 0.012*"jabra" + 0.012*"device" + 0.011*"recommend" + 0.010*"good" + 0.009*"best" + 0.008*"difficult"'),
#  (3,
#   '0.039*"money" + 0.036*"item" + 0.035*"great" + 0.031*"recommend" + 0.029*"impressed" + 0.026*"waste" + 0.025*"work" + 0.020*"doesn" + 0.020*"don" + 0.019*"charger"'),
#  (4,
#   '0.075*"good" + 0.072*"price" + 0.055*"product" + 0.031*"excellent" + 0.025*"purchase" + 0.023*"phone" + 0.017*"amazon" + 0.014*"sound" + 0.014*"great" + 0.014*"battery"'),
#  (24,
#   '0.046*"works" + 0.042*"fine" + 0.018*"product" + 0.017*"good" + 0.014*"just" + 0.014*"beep" + 0.010*"work" + 0.009*"recommend" + 0.009*"time" + 0.009*"wouldn"'),
#  (22,
#   '0.056*"like" + 0.030*"phone" + 0.029*"use" + 0.026*"thing" + 0.018*"talk" + 0.015*"good" + 0.012*"ear" + 0.011*"hear" + 0.011*"bought" + 0.011*"clarity"'),
#  (10,
#   '0.028*"headset" + 0.024*"time" + 0.022*"bluetooth" + 0.019*"long" + 0.016*"love" + 0.015*"small" + 0.014*"battery" + 0.012*"cool" + 0.011*"design" + 0.011*"great"'),
#  (2,
#   '0.044*"quality" + 0.028*"sound" + 0.027*"case" + 0.026*"piece" + 0.025*"use" + 0.018*"hands" + 0.017*"pretty" + 0.016*"excellent" + 0.015*"easy" + 0.013*"phone"'),
#  (5,
#   '0.040*"happy" + 0.033*"horrible" + 0.024*"phone" + 0.018*"product" + 0.015*"stay" + 0.015*"cheap" + 0.015*"sound" + 0.015*"absolutely" + 0.010*"away" + 0.010*"case"'),
#  (21,
#   '0.040*"service" + 0.031*"phone" + 0.030*"does" + 0.024*"customer" + 0.022*"better" + 0.017*"ear" + 0.015*"terrible" + 0.014*"highly" + 0.014*"product" + 0.012*"excellent"'),
#  (18,
#   '0.050*"comfortable" + 0.025*"ear" + 0.019*"ve" + 0.018*"useless" + 0.018*"order" + 0.015*"works" + 0.013*"great" + 0.012*"internet" + 0.012*"sound" + 0.012*"wind"'),
#  (20,
#   '0.048*"headset" + 0.020*"phone" + 0.019*"really" + 0.016*"best" + 0.015*"excellent" + 0.012*"easy" + 0.012*"bluetooth" + 0.012*"used" + 0.009*"far" + 0.008*"recommend"')]

# %%
# We can limit what is returned by specifying the number of topics we're interested in and the number of works to return
num_topics = 10
num_words = 5
for ti, topic in enumerate(lda.show_topics(num_topics = num_topics, num_words= num_words)):
    print("Topic: %d" % (ti))
    print (topic)
    print()
# Out:
# Topic: 0
# (18, '0.050*"comfortable" + 0.025*"ear" + 0.019*"ve" + 0.018*"useless" + 0.018*"order"')
#
# Topic: 1
# (21, '0.040*"service" + 0.031*"phone" + 0.030*"does" + 0.024*"customer" + 0.022*"better"')
#
# Topic: 2
# (9, '0.052*"phone" + 0.012*"worked" + 0.012*"ear" + 0.012*"color" + 0.012*"job"')
#
# Topic: 3
# (4, '0.075*"good" + 0.072*"price" + 0.055*"product" + 0.031*"excellent" + 0.025*"purchase"')
#
# Topic: 4
# (0, '0.023*"good" + 0.023*"don" + 0.018*"design" + 0.015*"service" + 0.014*"problems"')
#
# Topic: 5
# (12, '0.086*"phone" + 0.028*"worst" + 0.020*"new" + 0.018*"sturdy" + 0.015*"great"')
#
# Topic: 6
# (17, '0.021*"charger" + 0.018*"great" + 0.015*"works" + 0.013*"quality" + 0.012*"use"')
#
# Topic: 7
# (5, '0.040*"happy" + 0.033*"horrible" + 0.024*"phone" + 0.018*"product" + 0.015*"stay"')
#
# Topic: 8
# (14, '0.049*"poor" + 0.037*"good" + 0.036*"quality" + 0.025*"phone" + 0.019*"just"')
#
# Topic: 9
# (10, '0.028*"headset" + 0.024*"time" + 0.022*"bluetooth" + 0.019*"long" + 0.016*"love"')

# %%
#Similar method but without formatting
lda.print_topics(num_topics=3, num_words=5)
# Out:
# [(18,
#   '0.050*"comfortable" + 0.025*"ear" + 0.019*"ve" + 0.018*"useless" + 0.018*"order"'),
#  (2,
#   '0.044*"quality" + 0.028*"sound" + 0.027*"case" + 0.026*"piece" + 0.025*"use"'),
#  (21,
#   '0.040*"service" + 0.031*"phone" + 0.030*"does" + 0.024*"customer" + 0.022*"better"')]

# %% [markdown]
# Some topics will be clearer than others.  The following topics represent clear concepts:
# - Cooking and Recipes: 0.009 \* cup + 0.009 \* recipe + 0.007 \* make + 0.007 \* food + 0.006 \* sugar
# - Cooking and recipes: 0.013 \* butter + 0.010 \* baking + 0.010 \* dough + 0.009 \* cup + 0.009 \* sugar
# - Fashion and Style: 0.013 \* fashion + 0.006 \* like + 0.006 \* dress + 0.005 \* style

# %% [markdown]
# ## Word2Vec with `gensim`

# %% [markdown]
# ### Preparing the Input
# Starting from the beginning, gensim’s word2vec expects a sequence of sentences as its input. Each sentence a list of words (utf8 strings):

# %%
# Setup the body text
sentences = df.review.map(lambda review: review.split())

# %%
sentences
# Out:
# 1       [so, there, is, no, way, for, me, to, plug, it...
# 2                        [good, case,, excellent, value.]
# 5                             [great, for, the, jawbone.]
# 10      [tied, to, charger, for, conversations, lastin...
# 11                                 [the, mic, is, great.]
#                               ...
# 2925    [the, screen, does, get, smudged, easily, beca...
# 2930    [what, a, piece, of, junk.., i, lose, more, ca...
# 2934                   [item, does, not, match, picture.]
# 2935    [the, only, thing, that, disappoint, me, is, t...
# 2937    [you, can, not, answer, calls, with, the, unit...
# Name: review, Length: 1000, dtype: object

# %% [markdown]
# ### Training
# Word2vec accepts several parameters that affect both training speed and quality.
#
# One of them is for pruning the internal dictionary. Words that appear only once or twice in a billion-word corpus are probably uninteresting typos and garbage. In addition, there’s not enough data to make any meaningful training on those words, so it’s best to ignore them:
#
# **1
# model = Word2Vec(sentences, min_count=10)**
#
# Note: default value is 5
# A reasonable value for **min_count** is between 0-100, depending on the size of your dataset.
#
# Another parameter is the size of the **NN layers**, which correspond to the “degrees” of freedom the training algorithm has:
#
# **1
# model = Word2Vec(sentences, size=200)**
#
# Note: default value is 100
# Bigger size values require more training data, but can lead to better (more accurate) models. Reasonable values are in the tens to hundreds.
#
# The last of the major parameters (full list here) is for **training parallelization**, to speed up training:
#
# **1
# model = Word2Vec(sentences, workers=4)**
#
# Note: default = 1 worker = no parallelization
# The workers parameter has only effect if you have Cython installed. Without Cython, you’ll only be able to use one core because of the GIL (and word2vec training will be miserably slow).

# %%
# So lets train against our previously prepared data
model = Word2Vec(sentences, size = 100, window = 5, min_count = 5, workers = 4)

# I threw another parameter in there - of which there are many - what does it do?

# %% [markdown]
# ## Evaluating
# Word2vec training is an unsupervised task, there’s no good way to objectively evaluate the result. Evaluation depends on your end application.
#
# Google have released their testing set of about 20,000 syntactic and semantic test examples, following the “A is to B as C is to D” task: https://raw.githubusercontent.com/RaRe-Technologies/gensim/develop/gensim/test/test_data/questions-words.txt.
#
# Gensim support the same evaluation set, in exactly the same format:
#
# Once again, good performance on this test set doesn’t mean word2vec will work well in your application, or vice versa. It’s always best to evaluate directly on your intended task.

# %% [markdown]
# `Word2Vec` has many arguments:
# - `size` represents how many concepts or topics we should use
# - `window` represents how many words surrounding a sentence we should use as our original feature
# - `min_count` is the number of times that context or word must appear
# - `workers` is the number of CPU cores to use to speed up model training
#
# (Check http://radimrehurek.com/gensim/models/word2vec as needed)

# %% [markdown]
# ### Most similar words

# %% [markdown]
# The model has a `most_similar` function that helps find the words most similar to the one you queried.  This will return words that are most often used in the same context.

# %%
model.wv.most_similar(positive = ['great'])
# Out:
# [('and', 0.9992222785949707),
#  ('not', 0.9991952776908875),
#  ('is', 0.9991869330406189),
#  ('of', 0.9991730451583862),
#  ('with', 0.9991649389266968),
#  ('my', 0.9991316199302673),
#  ('it', 0.9991289377212524),
#  ('a', 0.9991236925125122),
#  ('the', 0.9991183280944824),
#  ('i', 0.9990901947021484)]

# %%
# That doesn't seem to line up with what I had in my mind. Let's have a look at the features available

vect.get_feature_names()

# Golly... that list is long. Now we're remembering the idea of pre-processing from last class.
# Out:
# ['10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '15',
#  '15g',
#  '18',
#  '20',
#  '2000',
#  '2005',
#  '2160',
#  '24',
#  '2mp',
#  '325',
#  '350',
#  '375',
#  '3o',
#  '42',
#  '44',
#  '45',
#  '4s',
#  '50',
#  '5020',
#  '510',
#  '5320',
#  '680',
#  '700w',
#  '8125',
#  '8525',
#  '8530',
#  'abhor',
#  'ability',
#  'able',
#  'abound',
#  'absolutel',
#  'absolutely',
#  'ac',
#  'accept',
#  'acceptable',
#  'access',
#  'accessable',
#  'accessing',
#  'accessory',
#  'accessoryone',
#  'accidentally',
#  'accompanied',
#  'according',
#  'activate',
#  'activated',
#  'activesync',
#  'actually',
#  'ad',
#  'adapter',
#  'adapters',
#  'add',
#  'addition',
#  'additional',
#  'address',
#  'adhesive',
#  'adorable',
#  'advertised',
#  'advise',
#  'aggravating',
#  'ago',
#  'alarm',
#  'allot',
#  'allow',
#  'allowing',
#  'allows',
#  'alot',
#  'aluminum',
#  'amazed',
#  'amazing',
#  'amazon',
#  'amp',
#  'ample',
#  'angeles',
#  'angle',
#  'answer',
#  'ant',
#  'antena',
#  'anti',
#  'apart',
#  'apartment',
#  'apparently',
#  'appealing',
#  'appearance',
#  'appears',
#  'applifies',
#  'appointments',
#  'area',
#  'arguing',
#  'armband',
#  'arrival',
#  'arrived',
#  'asia',
#  'ask',
#  'aspect',
#  'assumed',
#  'atleast',
#  'att',
#  'attacked',
#  'attractive',
#  'audio',
#  'authentic',
#  'auto',
#  'available',
#  'average',
#  'avoid',
#  'avoiding',
#  'away',
#  'awesome',
#  'awful',
#  'awkward',
#  'awsome',
#  'background',
#  'backlight',
#  'bad',
#  'balance',
#  'bar',
#  'barely',
#  'bargain',
#  'bars',
#  'basement',
#  'basic',
#  'basically',
#  'batteries',
#  'battery',
#  'beat',
#  'beats',
#  'beautiful',
#  'bed',
#  'beep',
#  'beeping',
#  'behing',
#  'believe',
#  'bells',
#  'belt',
#  'bend',
#  'best',
#  'better',
#  'beware',
#  'big',
#  'biggest',
#  'bills',
#  'bit',
#  'bitpim',
#  'black',
#  'blackberry',
#  'blacktop',
#  'bland',
#  'blew',
#  'blue',
#  'blueant',
#  'bluetoooth',
#  'bluetooth',
#  'bluetooths',
#  'bmw',
#  'book',
#  'booking',
#  'boost',
#  'boot',
#  'bose',
#  'bother',
#  'bottowm',
#  'bought',
#  'bougth',
#  'boy',
#  'brand',
#  'break',
#  'breakage',
#  'breaking',
#  'breaks',
#  'brilliant',
#  'broke',
#  'broken',
#  'browser',
#  'browsing',
#  'bt',
#  'bt250v',
#  'bt50',
#  'bubbling',
#  'bucks',
#  'buds',
#  'build',
#  'built',
#  'bulky',
#  'bumpers',
#  'button',
#  'buttons',
#  'buy',
#  'buyer',
#  'buyers',
#  'buying',
#  'buyit',
#  'buzzing',
#  'ca',
#  'cable',
#  'cables',
#  'calendar',
#  'called',
#  'calls',
#  'came',
#  'camera',
#  'canal',
#  'cancellation',
#  'cancelling',
#  'capability',
#  'capacity',
#  'car',
#  'card',
#  'care',
#  'careful',
#  'carried',
#  'carriers',
#  'carries',
#  'carry',
#  'case',
#  'cases',
#  'casing',
#  'cassette',
#  'cat',
#  'catching',
#  'caused',
#  'causing',
#  'cbr',
#  'cds',
#  'cell',
#  'cellphone',
#  'cellphones',
#  'cellular',
#  'cent',
#  'center',
#  'certain',
#  'certainly',
#  'changing',
#  'channel',
#  'charge',
#  'charged',
#  'charger',
#  'chargers',
#  'charges',
#  'charging',
#  'charm',
#  'cheap',
#  'cheaper',
#  'cheaply',
#  'cheapy',
#  'check',
#  'checked',
#  'child',
#  'china',
#  'chinese',
#  'choice',
#  'choices',
#  'christmas',
#  'cingulair',
#  'cingular',
#  'clarity',
#  'classy',
#  'clear',
#  'clearer',
#  'clearly',
#  'clever',
#  'clicks',
#  'clip',
#  'clipping',
#  'clips',
#  'clock',
#  'colleague',
#  'color',
#  'colored',
#  'colors',
#  'combination',
#  'come',
#  'comes',
#  'comfort',
#  'comfortable',
#  'comfortably',
#  'comfortible',
#  'coming',
#  'comments',
#  'commercials',
#  'communicate',
#  'communication',
#  'communications',
#  'commuter',
#  'company',
#  'comparably',
#  'compared',
#  'compete',
#  'competitors',
#  'complain',
#  'complained',
#  'complaint',
#  'complaints',
#  'completely',
#  'compliments',
#  'compromise',
#  'computer',
#  'concrete',
#  'conditions',
#  'confortable',
#  'confusing',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'constantly',
#  'constructed',
#  'construction',
#  'consumer',
#  'contact',
#  'contacted',
#  'contacting',
#  'contacts',
#  'continue',
#  'continues',
#  'contract',
#  'control',
#  'controls',
#  'contstruct',
#  'convenient',
#  'conversation',
#  'conversations',
#  'converter',
#  'cool',
#  'copier',
#  'copy',
#  'corded',
#  'correctly',
#  'cost',
#  'costs',
#  'couldn',
#  'counter',
#  'counterfeit',
#  'couple',
#  'coupon',
#  'course',
#  'cover',
#  'coverage',
#  'covered',
#  'crack',
#  'cracked',
#  'cradle',
#  'cradles',
#  'crap',
#  'crappy',
#  'crashed',
#  'crawl',
#  'creaks',
#  'crisp',
#  'cumbersome',
#  'current',
#  'currently',
#  'curve',
#  'customer',
#  'cut',
#  'cute',
#  'cutouts',
#  'cuts',
#  'd807',
#  'damage',
#  'darn',
#  'data',
#  'date',
#  'day',
#  'days',
#  'dead',
#  'deaf',
#  'deal',
#  'decade',
#  'decent',
#  'decision',
#  'defeats',
#  'defect',
#  'defective',
#  'deffinitely',
#  'definitely',
#  'definitly',
#  'delay',
#  'delivery',
#  'described',
#  'description',
#  'design',
#  'designed',
#  'designs',
#  'despite',
#  'destination',
#  'destroying',
#  'detachable',
#  'detailed',
#  'development',
#  'device',
#  'devices',
#  'dialing',
#  'did',
#  'didn',
#  'died',
#  'dieing',
#  'different',
#  'difficult',
#  'directed',
#  'directions',
#  'directly',
#  'dirty',
#  'disapoinment',
#  'disapointing',
#  'disappoint',
#  'disappointed',
#  'disappointing',
#  'disappointment',
#  'discarded',
#  'discomfort',
#  'disconnected',
#  'discount',
#  'disgusting',
#  'display',
#  'displeased',
#  'disposable',
#  'dissapointed',
#  'dissapointing',
#  'distorted',
#  'distracting',
#  'dit',
#  'division',
#  'dna',
#  'docking',
#  'does',
#  'doesn',
#  'doing',
#  'dollar',
#  'don',
#  'dont',
#  'double',
#  'download',
#  'downloading',
#  'dozen',
#  'dozens',
#  'drain',
#  'drained',
#  'drains',
#  'drawback',
#  'driving',
#  'drivng',
#  'droid',
#  'drop',
#  'dropped',
#  'dropping',
#  'drops',
#  'dual',
#  'durable',
#  'dustpan',
#  'dying',
#  'e2',
#  'e715',
#  'ear',
#  'earbud',
#  'earbuds',
#  'earbugs',
#  'eargels',
#  'earlier',
#  'earpad',
#  'earphone',
#  'earphones',
#  'earpiece',
#  'earpieces',
#  'ears',
#  'earset',
#  'ease',
#  'easier',
#  'easily',
#  'easy',
#  'echo',
#  'edge',
#  'effect',
#  'effective',
#  'effects',
#  'effort',
#  'electronics',
#  'elegant',
#  'embarassing',
#  'embarrassing',
#  'embedded',
#  'encourage',
#  'end',
#  'ended',
#  'ends',
#  'engineered',
#  'enjoy',
#  'enter',
#  'entertainment',
#  'entire',
#  'env',
#  'equipment',
#  'era',
#  'ergonomic',
#  'ericson',
#  'ericsson',
#  'especially',
#  'essentially',
#  'europe',
#  'eventually',
#  'everyday',
#  'exactly',
#  'exceeds',
#  'excelent',
#  'excellent',
#  'excels',
#  'exceptional',
#  'excessive',
#  'exchange',
#  'exchanged',
#  'excited',
#  'exclaim',
#  'excrutiatingly',
#  'exercise',
#  'existing',
#  'expect',
#  'expectations',
#  'expected',
#  'expensive',
#  'experience',
#  'experienced',
#  'explain',
#  'extended',
#  'exterior',
#  'external',
#  'extra',
#  'extremely',
#  'eye',
#  'fabulous',
#  'face',
#  'faceplates',
#  'fact',
#  'factor',
#  'failed',
#  'fails',
#  'fairly',
#  'fall',
#  'falling',
#  'falls',
#  'family',
#  'fantastic',
#  'far',
#  'fast',
#  'faster',
#  'father',
#  'favorite',
#  'feature',
#  'features',
#  'fee',
#  'feel',
#  'feels',
#  'feet',
#  'felt',
#  'fi',
#  'figure',
#  'file',
#  'finally',
#  'finds',
#  'fine',
#  'fingers',
#  'finished',
#  'fit',
#  'fits',
#  'fixes',
#  'flash',
#  'flaw',
#  'flawed',
#  'flawless',
#  'flawlessly',
#  'flaws',
#  'flimsy',
#  'flip',
#  'flipphones',
#  'fliptop',
#  'floor',
#  'floppy',
#  'flops',
#  'flush',
#  'fm',
#  'followed',
#  'fond',
#  'fooled',
#  'forced',
#  'forever',
#  'forgeries',
#  'forget',
#  'forgot',
#  'form',
#  'fourth',
#  'fraction',
#  'free',
#  'freedom',
#  'freeway',
#  'freezes',
#  'frequently4',
#  'frequentyly',
#  'friendly',
#  'friends',
#  'frog',
#  'frustration',
#  'fry',
#  'ft',
#  'fulfills',
#  'fully',
#  'fun',
#  'function',
#  'functional',
#  'functionality',
#  'functions',
#  'funny',
#  'gadget',
#  'gadgets',
#  'games',
#  'garbage',
#  'garbled',
#  'gave',
#  'geeky',
#  'gels',
#  'generally',
#  'gentle',
#  'genuine',
#  'gets',
#  'getting',
#  'gimmick',
#  'girl',
#  'given',
#  'giving',
#  'glad',
#  'glare',
#  'glasses',
#  'glove',
#  'glued',
#  'goes',
#  'going',
#  'gonna',
#  'good',
#  'good7',
#  'gosh',
#  'got',
#  'gotten',
#  'graphics',
#  'great',
#  'greater',
#  'grey',
#  'grip',
#  'grtting',
#  'guess',
#  'gx2',
#  'h500',
#  'hair',
#  'hand',
#  'handheld',
#  'hands',
#  'handset',
#  'handsfree',
#  'handy',
#  'happened',
#  'happening',
#  'happens',
#  'happier',
#  'happy',
#  'hard',
#  'hardly',
#  'hat',
#  'hate',
#  'hated',
#  'haul',
#  'haven',
#  'having',
#  'headbands',
#  'headphones',
#  'headset',
#  'headsets',
#  'hear',
#  'hearing',
#  'heavy',
#  'help',
#  'helpful',
#  'hey',
#  'high',
#  'highest',
#  'highly',
#  'highy',
#  'hinge',
#  'hit',
#  'hitch',
#  'hold',
#  'holder',
#  'holding',
#  'holds',
#  'holster',
#  'home',
#  'hook',
#  'hoped',
#  'hoping',
#  'horrible',
#  'hot',
#  'hour',
#  'hours',
#  'hoursthe',
#  'house',
#  'hs850',
#  'huge',
#  'humans',
#  'humming',
#  'hurt',
#  'hybrid',
#  'hype',
#  'iam',
#  'idea',
#  'ideal',
#  'igo',
#  'ill',
#  'im',
#  'imac',
#  'images',
#  'imagine',
#  'immediately',
#  'important',
#  'impossible',
#  'impressed',
#  'impressive',
#  'improper',
#  'improve',
#  'improvement',
#  'inches',
#  'included',
#  'incoming',
#  'inconspicuous',
#  'increase',
#  'incrediable',
#  'incredible',
#  'incredibly',
#  'indoors',
#  'industrial',
#  'inexcusable',
#  'inexpensive',
#  'infatuated',
#  'inform',
#  'infra',
#  'infuriating',
#  'insert',
#  'inside',
#  'install',
#  'installed',
#  'instance',
#  'instead',
#  'instruction',
#  'instructions',
#  'integrated',
#  'intended',
#  'interested',
#  'interface',
#  'intermittently',
#  'internet',
#  'invented',
#  'investment',
#  'iphone',
#  'ipod',
#  'ipods',
#  'ir',
#  'irda',
#  'iriver',
#  'isn',
#  'issues',
#  'item',
#  'items',
#  'jabra',
#  'jabra350',
#  'jack',
#  'jawbone',
#  'jerks',
#  'jiggle',
#  'job',
#  'joke',
#  'joy',
#  'juice',
#  'junk',
#  'just',
#  'jx',
#  'keen',
#  'keeping',
#  'keeps',
#  'kept',
#  'key',
#  'keyboard',
#  'keypad',
#  'keypads',
#  'keys',
#  'killer',
#  'kind',
#  'kindle',
#  'kitchen',
#  'kits',
#  'knock',
#  'know',
#  'knows',
#  'krussel',
#  'l7c',
#  'lacking',
#  'land',
#  'lap',
#  'laptop',
#  'large',
#  'lasted',
#  'lasting',
#  'lasts',
#  'latch',
#  'lately',
#  'later',
#  'latest',
#  'laughing',
#  'leaf',
#  'leaks',
#  'learned',
#  'leather',
#  'left',
#  'lense',
#  'leopard',
#  'lesson',
#  'let',
#  'letting',
#  'lg',
#  'life',
#  'light',
#  'lightly',
#  'lights',
#  'lightweight',
#  'like',
#  'liked',
#  'likes',
#  'line',
#  'linked',
#  'linking',
#  'linksys',
#  'listener',
#  'listening',
#  'lit',
#  'literally',
#  'little',
#  'living',
#  'll',
#  'loads',
#  'lock',
#  'locked',
#  'locks',
#  'logitech',
#  'long',
#  'longer',
#  'look',
#  'looking',
#  'looks',
#  'loop',
#  'loops',
#  'loose',
#  'looses',
#  'los',
#  'lose',
#  'lost',
#  'lot',
#  'lots',
#  'loud',
#  'louder',
#  'loudest',
#  'loudspeaker',
#  'lousy',
#  'love',
#  'loved',
#  'loves',
#  'low',
#  'luck',
#  'machine',
#  'magical',
#  'magnetic',
#  'mail',
#  'mainly',
#  'maintain',
#  'maintains',
#  'major',
#  'majority',
#  'make',
#  'makes',
#  'making',
#  'managed',
#  'management',
#  'manual',
#  'manufacturer',
#  'mark',
#  'market',
#  'match',
#  'material',
#  'max',
#  'means',
#  'mechanism',
#  'media',
#  'mediocre',
#  'mega',
#  'megapixels',
#  'memory',
#  'mention',
#  'mentioned',
#  'menus',
#  'mere',
#  'mess',
#  'message',
#  'messages',
#  'messaging',
#  'messes',
#  'metal',
#  'metro',
#  'mic',
#  'microphone',
#  'microsoft',
#  'mind',
#  'mini',
#  'mins',
#  'minute',
#  'minutes',
#  'misleading',
#  'missed',
#  'mistake',
#  'mobile',
#  'mode',
#  'model',
#  'modest',
#  'money',
#  'monkeys',
#  'month',
#  'months',
#  'morning',
#  'mother',
#  'moto',
#  'motor',
#  'motorola',
#  'motorolas',
#  'moving',
#  'mp3',
#  'mp3s',
#  'muddy',
#  'muffled',
#  'multiple',
#  'music',
#  'mute',
#  'nano',
#  'navigate',
#  'near',
#  'nearly',
#  'neat',
#  'need',
#  'needed',
#  'needless',
#  'needs',
#  'negatively',
#  'network',
#  'new',
#  'ngage',
#  'nice',
#  'nicely',
#  'nicer',
#  'night',
#  'nightmare',
#  'noise',
#  'noises',
#  'nokia',
#  'normal',
#  'normally',
#  'note',
#  'noted',
#  'notice',
#  'noticed',
#  'number',
#  'numbers',
#  'numerous',
#  'nyc',
#  'obviously',
#  'occupied',
#  'odd',
#  'oem',
#  'offering',
#  'offers',
#  'official',
#  'oh',
#  'ok',
#  'old',
#  'ones',
#  'online',
#  'oozes',
#  'open',
#  'opens',
#  'operate',
#  'operates',
#  'optimal',
#  'option',
#  'options',
#  'order',
#  'ordered',
#  ...]

# %%
# Lets remember what we have to work with
sentences
# Out:
# 1       [so, there, is, no, way, for, me, to, plug, it...
# 2                        [good, case,, excellent, value.]
# 5                             [great, for, the, jawbone.]
# 10      [tied, to, charger, for, conversations, lastin...
# 11                                 [the, mic, is, great.]
#                               ...
# 2925    [the, screen, does, get, smudged, easily, beca...
# 2930    [what, a, piece, of, junk.., i, lose, more, ca...
# 2934                   [item, does, not, match, picture.]
# 2935    [the, only, thing, that, disappoint, me, is, t...
# 2937    [you, can, not, answer, calls, with, the, unit...
# Name: review, Length: 1000, dtype: object

# %%
# What if I built a way to filter out more pertinent words

sentences2 = list(map(lambda sentence: list(filter(lambda word: word in vect.get_feature_names(), sentence)), sentences))

# %%
# Let's visualize it again to see what happened to my sentences. 
sentences2

# That looks better - shorter lists of the words related to the feature_names
# Out:
# [['way', 'plug', 'unless'],
#  ['good', 'excellent'],
#  ['great'],
#  ['tied', 'charger', 'conversations', 'lasting', '45'],
#  ['mic'],
#  ['jiggle', 'plug', 'line', 'right', 'decent'],
#  ['dozen', 'imagine', 'fun', 'sending'],
#  ['razr'],
#  ['needless', 'wasted'],
#  ['waste', 'money'],
#  ['sound', 'quality'],
#  ['impressed', 'going', 'original', 'battery', 'extended'],
#  ['seperated',
#   'mere',
#   'ft',
#   'started',
#   'notice',
#   'excessive',
#   'static',
#   'garbled',
#   'sound'],
#  ['good', 'quality'],
#  ['design', 'ear', 'comfortable'],
#  ['highly', 'recommend', 'blue', 'tooth'],
#  ['advise'],
#  ['far'],
#  ['works'],
#  ['clicks', 'place', 'way', 'makes', 'wonder', 'long', 'mechanism'],
#  ['went', 'website', 'followed', 'pair'],
#  ['bought', 'use', 'kindle', 'absolutely', 'loved'],
#  ['commercials'],
#  ['run', 'new', 'battery', 'bars', 'days'],
#  ['bought', 'mother', 'problem'],
#  ['great', 'pocket', 'pc', 'phone'],
#  ['owned', 'phone', 'months', 'say', 'best', 'mobile', 'phone'],
#  ['think', 'instructions', 'provided', 'helpful'],
#  ['people', 'hear', 'talk', 'pull', 'earphone', 'talk'],
#  ['hold'],
#  ['simple', 'little', 'phone', 'breakage'],
#  ['product', 'ideal', 'people', 'like', 'ears'],
#  ['unusable', 'moving', 'car', 'freeway'],
#  ['years', 'left', 'contract', 'hate'],
#  ['car',
#   'charger',
#   'ac',
#   'charger',
#   'included',
#   'make',
#   'sure',
#   'run',
#   'recommended'],
#  ['need', 'mins', 'phone', 'book', 'time', 'turn', 'life'],
#  ['kept'],
#  ['poor', 'talk', 'time'],
#  ['case', 'great', 'works', 'fine'],
#  ['worthless'],
#  ['great', 'camera', 'thats', 'pics', 'nice', 'clear', 'great', 'picture'],
#  ['impressed'],
#  ['nice', 'headset', 'priced'],
#  ['hear', 'garbage'],
#  ['excellent', 'bluetooth'],
#  ['features', 'want'],
#  ['right', 'mind', 'gonna', 'buy'],
#  ['arguing', 'verizon', 'regarding', 'dropped', 'calls', 'returned', 'phones'],
#  ['case'],
#  ['disappointed'],
#  ['loud', 'turn', 'like'],
#  ['good', 'protection', 'does', 'make', 'phone'],
#  ['usable',
#   'keyboard',
#   'actually',
#   'turns',
#   'pda',
#   'useful',
#   'machine',
#   'instead',
#   'just',
#   'neat'],
#  ['phone', 'pretty', 'sturdy', 'large', 'problems'],
#  ['love'],
#  ['fine', 'reasonable', 'price'],
#  [],
#  ['dropped', 'phone', 'stream', 'submerged', '15', 'seconds', 'works'],
#  ['happy', '510', 'complaints', 'regarding', 'sound', 'quality'],
#  ['buttons'],
#  ['essentially', 'forget', 'tech'],
#  ['really', 'recommend', 'faceplates', 'looks', 'elegant'],
#  ['headphones', 'great', 'think', 'best', 'purchase', 'years'],
#  ['buy', 'different', 'phone'],
#  ['hold', 'phone', 'particular', 'angle', 'party', 'hear'],
#  ['big',
#   'drawback',
#   'mp3',
#   'player',
#   'buttons',
#   'cover',
#   'let',
#   'pause',
#   'skip',
#   'songs',
#   'lock'],
#  ['week', 'later', 'activated', 'suddenly'],
#  ['feels', 'comfortable', 'headsets', 'wear', 'glasses', 'gets', 'way'],
#  ['great', 'ipods'],
#  ['device', 'great'],
#  ['mic'],
#  ['bmw', 'series', 'fairly', 'trouble', 'hearing', 'person'],
#  ['great'],
#  ['nice', 'docking', 'station', 'home'],
#  ['beautiful'],
#  ['love'],
#  ['buy', 'advertised'],
#  ['great', 'little'],
#  ['love', 'phone', 'handy', 'lot', 'features'],
#  ['purchased', 'days', 'longer'],
#  ['wear', 'everyday', 'holds'],
#  ['good'],
#  ['arrived', 'works'],
#  ['battery', 'runs'],
#  ['item', 'worked', 'broke', 'months'],
#  ['headsets', 'easy', 'use', 'loves'],
#  ['phone', 'works'],
#  ['construction', 'headsets'],
#  ['product', 'excellent', 'works', 'better', 'verizon', 'boy'],
#  ['phone', 'loads'],
#  ['product',
#   'costs',
#   'expect',
#   'work',
#   'far',
#   'better',
#   'greater',
#   'ease',
#   'thing'],
#  [],
#  ['worked'],
#  ['ear', 'buds', 'play', 'music'],
#  ['dont', 'waste'],
#  ['order'],
#  ['plan', 'use', 'car', 'forget'],
#  ['product', 'waaay'],
#  ['best', 'far', 'tried', 'bluetooths', 'best', 'quality', 'ease'],
#  ['disappointed'],
#  ['integrated', 'seamlessly', 'motorola', 'razr'],
#  ['buyer', 'flush', 'money', 'right'],
#  ['definitely'],
#  ['price', 'good', 'free', 'shipping', 'good'],
#  ['received',
#   'supposedly',
#   'new',
#   'motorola',
#   '375',
#   'apparently',
#   'match',
#   'phone'],
#  ['camera', 'nice', 'pictures', 'cool', 'styles', 'like', 'black'],
#  ['huge', 'design', 'flaw', 'using', 'think'],
#  ['love',
#   '350',
#   'jabra350',
#   'bluetooth',
#   'headset',
#   'reception',
#   'good',
#   'ear',
#   'piece',
#   'comfortable'],
#  ['rated',
#   'impressive',
#   'renders',
#   'images',
#   'fall',
#   'expectations',
#   'relatively',
#   'high'],
#  ['purcashed', 'car', 'charger', 'does'],
#  ['sound',
#   'quality',
#   'end',
#   'use',
#   'headset',
#   'wife',
#   'ask',
#   'wife',
#   'use',
#   'headset'],
#  ['phone', 'slim', 'light', 'display'],
#  ['little',
#   'geeky',
#   'think',
#   'thats',
#   'sex',
#   'toast',
#   'rocks',
#   'oozes',
#   'sex',
#   'right',
#   'battery',
#   'embedded',
#   'sleek',
#   'stylish',
#   'leather'],
#  ['great', 'fast'],
#  ['absolutely'],
#  ['keyboard',
#   'nice',
#   'compromise',
#   'qwerty',
#   'basic',
#   'cell',
#   'phone',
#   'number'],
#  ['got', 'phone', 'end', 'completely', 'unhappy'],
#  ['comfortable'],
#  ['winner'],
#  [],
#  ['tried', 'different', 'earpieces', 'cell', 'phone', 'jabra', 'fits', 'ear'],
#  ['strong'],
#  ['iam', 'pleased'],
#  ['bad'],
#  ['gets', 'job'],
#  ['great'],
#  ['basically', 'service'],
#  ['did', 'work', 'cell', 'phone', 'plug', 'set'],
#  ['bluetooth', 'really', 'like'],
#  ['bt', 'headset'],
#  ['small', 'realize', 'getting', 'used'],
#  ['accompanied', 'software'],
#  ['headset', 'works', 'great', 'packaged', 'nicely', 'avoid'],
#  ['definitly'],
#  [],
#  ['majority', 'logitech', 'earbud', 'headsets'],
#  ['good', 'stuff'],
#  ['headset', 'works', 'just'],
#  ['house', 'getting', 'dropped', 'coverage', 'upstairs', 'coverage'],
#  ['voice', 'recognition'],
#  [],
#  ['different', 'minute', 'experienced', 'drops', 'area'],
#  ['happy'],
#  [],
#  ['phone', 'takes', 'forever', 'charge', 'like', 'hours'],
#  ['got', 'phone', 'reccomendation', 'relative', 'glad'],
#  ['waste'],
#  ['reception'],
#  ['items', 'stated', 'included', 'description'],
#  ['screen', 'just', 'went', 'black'],
#  ['hoping'],
#  ['audio', 'quality'],
#  ['absolutely', 'problem', 'headset', 'linking', '8530', 'blackberry'],
#  ['know', 'sounds', 'like', 'sketchy', 'technology', 'work', 'works'],
#  ['bought', 'wired', 'headphones', 'sound', 'better'],
#  ['phone',
#   'fast',
#   'sending',
#   'kind',
#   'messages',
#   'web',
#   'browsing',
#   'significantly',
#   'faster',
#   'previous',
#   'phones'],
#  ['nice', 'quality', 'unlike', 'cheap'],
#  ['item', 'fantastic', 'works'],
#  ['just', 'love'],
#  ['w810i', 'just'],
#  ['whine', 'use', 'thing', 'like'],
#  ['great'],
#  ['essentially', 'communications', 'tool', 'does'],
#  ['works', 'like', 'work', 'got'],
#  ['maintain',
#   'monkeys',
#   'make',
#   'just',
#   'obviously',
#   'share',
#   'dna',
#   'copy',
#   'design'],
#  ['great'],
#  ['work', 'bougth', 'l7c'],
#  ['look', 'sharp', 'screen', 'nice', 'great'],
#  [],
#  ['thing', 'hate', 'mode', 'set', 'button'],
#  ['excellent'],
#  ['thank', 'wasting'],
#  ['audio', 'quality'],
#  ['igo', 'chargers', 'tips', 'really'],
#  ['file', 'browser', 'offers', 'options'],
#  ['superb', 'phone', 'great'],
#  ['connected', 'phone', 'worked', 'like', 'charm', 'phone', 'pocket'],
#  ['latest', 'os', 'likes', 'slow', 'crawl', 'lock'],
#  ['recognizes', 'phone', 'storage'],
#  ['like', 'loud', 'buzzing', 'override', 'phone'],
#  ['buy'],
#  ['bluetoooth', 'headset', 'time', 'comfortable', 'way', 'fits'],
#  ['sound', 'quality', 'good', 'functionality'],
#  ['phone', 'thorn', 'really', 'abhor'],
#  ['recently', 'problems', 'stay', 'connected', '10', 'minutes'],
#  [],
#  ['design'],
#  ['great'],
#  ['waste', '13'],
#  ['check', 'voice', 'mail', 'keypad', 'backlight', 'turns', 'seconds'],
#  ['replacement', 'died'],
#  ['ring', 'good', 'phone'],
#  ['lately', 'extremely', 'nice', 'helpful'],
#  ['problems', 'wit', 'hit', 'dropping', 'signal'],
#  [],
#  ['light', 'hardly', 'notice'],
#  ['love'],
#  ['bad'],
#  ['pleather', 'case'],
#  ['useless', 'simply'],
#  ['color', 'prettier', 'thought', 'graphics', 'incredibly'],
#  ['think', 'good'],
#  ['makes', 'strange', 'ticking', 'noises', 'ends'],
#  ['best', 'electronics', 'available', 'fm'],
#  ['battery', 'lasts'],
#  ['great', 'impressed'],
#  ['mega', 'pixel', 'reasonably'],
#  ['nearly', 'years', 'worked', 'great'],
#  ['good', 'transmit'],
#  ['sending'],
#  ['did',
#   'bother',
#   'contacting',
#   'company',
#   'dollar',
#   'product',
#   'learned',
#   'lesson',
#   'bought',
#   'form',
#   'online'],
#  ['hate', 'avoid', 'phone'],
#  ['great', 'price'],
#  ['range', 'able', 'roam', 'house', 'phone', 'living', 'room', 'quality'],
#  ['fast'],
#  ['highly', 'recommend'],
#  ['recommend'],
#  ['like', 'felt', 'like', 'crack'],
#  ['worst', 'phone'],
#  ['infatuated'],
#  ['freezes'],
#  ['kind', 'embarrassing', 'use', 'looks', 'embarrassing', 'company'],
#  ['lightweight', 'great'],
#  ['expected', 'better', 'consumer', 'experience'],
#  ['horrible', 'tick', 'sound', 'background', 'calls', 'experienced'],
#  ['certainly', 'comfortable', 'functionality'],
#  ['usually', 'like', 'headbands', 'lightweight', 'mess'],
#  ['bit'],
#  ['phone', 'year', 'tell'],
#  ['ordered', 'sony', 'ericsson', 'w810i', 'think', 'worked', 'used'],
#  ['battery', 'completely', 'useless'],
#  ['big', 'waste'],
#  ['waste'],
#  ['great', 'sound'],
#  ['really', 'pleased', 'product'],
#  ['favorite', 'purchases'],
#  ['best', 'bluetooth'],
#  ['authentic', 'leather', 'nice', 'shine', 'comfort', 'recommend', 'case'],
#  ['excited', 'headset', 'thought', 'really'],
#  ['make', 'mistake'],
#  ['big', 'disappointment', 'calendar'],
#  ['phone', 'unusable'],
#  ['worst', 'customer', 'service'],
#  ['additional', 'ear', 'gels', 'instructions'],
#  ['defeats', 'purpose', 'bluetooth'],
#  ['worth'],
#  ['excellent', 'wallet', 'type', 'phone'],
#  ['nice', 'headphones', 'price', 'work'],
#  ['internet', 'excrutiatingly'],
#  ['comfortable', 'wear', 'probably', 'important', 'aspect', 'using'],
#  ['fits', 'like', 'glove'],
#  ['gosh', 'best', 'phone'],
#  ['attractive', 'appears', 'good'],
#  ['love', 'features', 'form'],
#  ['product', 'strong', 'smell', 'unbearable', 'caused', 'return'],
#  ['poor', 'quality'],
#  ['cable', 'looks'],
#  ['great'],
#  ['excellent', 'hands', 'free'],
#  ['great', 'using', 'home'],
#  ['good', 'product', 'incredible'],
#  ['month', 'worked', 'flawlessly'],
#  ['works'],
#  ['absolutel'],
#  ['work'],
#  ['battery', 'life', 'real'],
#  ['returned', 'hours'],
#  ['great'],
#  ['waste'],
#  ['love'],
#  ['drain', 'potentially', 'fry'],
#  ['worked'],
#  ['unreliable', 'giving'],
#  ['gave', 'stars', 'sound'],
#  ['avoid'],
#  ['reversible', 'plug', 'works'],
#  ['wasted', 'little', 'money'],
#  ['good'],
#  ['best', 'rotating'],
#  ['comfort'],
#  ['good', 'good'],
#  ['love'],
#  ['wear'],
#  ['impressed', 'headset'],
#  ['got', 'small'],
#  ['great'],
#  ['recommend', 'buying'],
#  ['piece'],
#  ['poorly', 'contstruct'],
#  ['item',
#   'installed',
#   'let',
#   'charged',
#   'overnite',
#   'working',
#   'good',
#   'problems'],
#  ['great'],
#  ['buy'],
#  ['excellent'],
#  ['purchase'],
#  ['voice', 'recognition', 'handset'],
#  ['hands', 'best', 'phone'],
#  ['works',
#   'cat',
#   'attacked',
#   'phone',
#   'scratched',
#   'protective',
#   'strip',
#   'instead',
#   'destroying'],
#  ['works', 'priced'],
#  ['customer', 'service'],
#  ['battery', 'life', 'long', 'motorola', 'razor'],
#  ['sending'],
#  ['know', 'wise'],
#  ['shouldve', 'invented'],
#  ['good'],
#  ['worked',
#   'device',
#   'certainly',
#   'engineered',
#   'clever',
#   'way',
#   'construction',
#   'feels'],
#  ['received', 'quickly', 'works'],
#  ['working'],
#  ['people', 'microphone'],
#  ['old', 'nokia', '2160', 'tracfone', 'holds', 'charge', 'lot', 'better'],
#  ['care', 'consumer'],
#  ['good', 'got', 'really'],
#  ['instruction', 'manual'],
#  ['slim', 'fit', 'alarm', 'clock', 'docking', 'station', 'removing'],
#  ['phone', 'holds', 'charge', 'like', 'did'],
#  ['battery', 'unreliable', 'service', 'use'],
#  ['uncomfortable',
#   'sound',
#   'quality',
#   'quite',
#   'poor',
#   'compared',
#   'phone',
#   'previous',
#   'wired',
#   'headset',
#   'plugged'],
#  ['gotten', 'lot', 'compliments'],
#  ['definitely', 'state', 'does', 'allow', 'cell', 'phone', 'usage'],
#  ['want', 'money'],
#  ['love'],
#  ['happy'],
#  ['ordered', 'product', 'unhappy'],
#  ['ngage', 'lacking'],
#  ['able', 'voice', 'dialing', 'car'],
#  ['bars', 'cell', 'phone', 'hear'],
#  ['good', 'low'],
#  ['riingtones'],
#  ['plug', 'did', 'work'],
#  ['amazon'],
#  ['rip', 'charge'],
#  [],
#  ['battery', 'working', 'replacement', 'original', 'came', 'phone', 'years'],
#  ['reception'],
#  ['fits', 'comfortably', 'sound', 'clear', 'charge', 'lasts', 'couple'],
#  ['quality', 'sound', 'mess', 'sound', 'ipod', 'sound', 'buttons'],
#  ['long', 'lasting', 'battery', 'recharge', 'frequentyly', 'flip'],
#  ['obviously', 'problem'],
#  [],
#  ['inexpensive', 'expected', 'better'],
#  ['practically',
#   'useless',
#   'did',
#   'add',
#   'kind',
#   'boost',
#   'reception',
#   'bought'],
#  ['excellent', 'sound'],
#  [],
#  ['piece', 'junk', 'broke', 'phone'],
#  ['new', 'battery', 'works', 'great'],
#  ['worst', 'customer'],
#  ['dropped', 'phone', 'times', 'concrete', 'phone', 'great'],
#  ['reception', 'terrible'],
#  ['good', 'audio'],
#  ['little',
#   'device',
#   'transformed',
#   'organizational',
#   'capability',
#   'life',
#   'lot'],
#  ['sitting', 'cradle', 'headset', 'lost'],
#  ['jerks'],
#  ['works', 'like', 'works'],
#  ['nice', 'good', 'battery'],
#  ['network', 'coverage', 'los', 'angeles'],
#  ['excellent', 'starter', 'wireless'],
#  ['loudspeaker', 'option', 'bumpers', 'lights'],
#  ['thing', 'think', 'improve', 'sound', 'leaks'],
#  ['reception'],
#  ['phone', 'gets', 'extremely'],
#  ['microphone', 'works', 'people', 'applifies'],
#  ['nice', 'design'],
#  ['phone', 'case', 'going', 'save', 'specially', 'dropped', 'face'],
#  ['easy', 'clear', 'reception'],
#  ['bad', 'way'],
#  ['definitely', 'good'],
#  ['awesome'],
#  ['waste'],
#  ['ordered', 'motorola', 'data', 'got', 'finished', 'working'],
#  ['love'],
#  ['looking', 'headset', 'long', 'time', 'got'],
#  ['drivng', 'headset', 'starts', 'ringing'],
#  ['display', 'excellent', 'camera', 'good'],
#  ['battery', 'life'],
#  ['worst', 'phone'],
#  ['good',
#   'worked',
#   'started',
#   'having',
#   'problems',
#   'auto',
#   'reverse',
#   'tape'],
#  ['embarassing', 'ears', 'hurt', 'try', 'push', 'ear', 'plug'],
#  ['protects', 'phone'],
#  ['average', 'phone', 'bad', 'battery', 'life', 'operates', 'weak'],
#  ['clear', 'skype', 'long', 'battery', 'long'],
#  ['soyo', 'technology'],
#  ['great', 'hands', 'free'],
#  ['self', 'portraits', 'outside'],
#  ['problem'],
#  ['trying', 'handsfree', 'gadgets', 'finally', 'works'],
#  ['magical'],
#  ['worst', 'piece', 'crap', 'verizon', 'customer'],
#  ['poor', 'sound'],
#  ['best', 'phone', 'market'],
#  ['worked'],
#  ['company', 'shipped', 'product', 'promptly', 'works'],
#  ['exactly'],
#  ['picture', 'resolution', 'far', 'phones', 'offering'],
#  ['great'],
#  ['excellent', 'satisfied'],
#  ['highly', 'recommend', 'encourage', 'people'],
#  ['better'],
#  ['using', 'left', 'thing', 'stay'],
#  ['great', 'product'],
#  ['sounds', 'good', 'reasonably', 'priced', 'simple'],
#  ['sure', 'item', 'work', 'recieve'],
#  ['disappointment'],
#  ['prompt'],
#  ['excellent', 'product'],
#  ['pleased'],
#  ['waste', 'money'],
#  ['especially', 'love', 'long', 'battery'],
#  ['stupid',
#   'buying',
#   'new',
#   'car',
#   'headphones',
#   'car',
#   'kits',
#   'time',
#   'new',
#   'phone',
#   'comes'],
#  ['works'],
#  ['plantronics', 'bluetooth', 'excelent'],
#  ['came',
#   'verizon',
#   'cingulair',
#   'nicer',
#   'cell',
#   'thing',
#   'noticed',
#   'really',
#   'bad'],
#  ['looking', 'new'],
#  ['highly', 'recommend', 'device'],
#  ['jawbone', 'era', 'awesome'],
#  ['received',
#   'white',
#   'colored',
#   'battery',
#   'goes',
#   'dead',
#   'couple',
#   'hoursthe',
#   'original',
#   'used',
#   'week',
#   'lasts',
#   'longer',
#   'thereplacement'],
#  ['year', 'battery', 'went', 'completely', 'dead'],
#  ['used', 'phone'],
#  ['awesome', 'new', 'look', 'fall'],
#  ['phone', 'cheaply'],
#  ['att', 'sound', 'distorted', 'yell'],
#  ['plastic', 'breaks', 'really', 'easy'],
#  ['price', 'good'],
#  ['make', 'mistake'],
#  ['oh', 'forgot', 'mention', 'weird', 'color', 'effect'],
#  ['using', 'iriver', 'spinn', 'fits'],
#  ['area', 'unit', 'fond', 'magnetic'],
#  ['psyched', 'phone', 'appointments', 'contacts', 'gets', 'great'],
#  ['thing', 'phone', 'work', 'like'],
#  ['note', 'appearance', 'really', 'looks', 'especially', 'black'],
#  ['really'],
#  ['sanyo', 'survived', 'dozens', 'drops', 'blacktop', 'ill'],
#  ['fantastic'],
#  ['finds', 'cell', 'phone', 'right', 'away', 'enter'],
#  ['low'],
#  ['highly', 'recommend', 'modest', 'priced', 'cellular'],
#  ['does', 'better', 'reception', 'clarity', 'phone'],
#  ['warning', 'stay'],
#  ['wish', 'return', 'unit'],
#  ['awsome', 'device', 'works'],
#  ['used', 'talk', 'hours', 'battery', 'literally', 'drained'],
#  ['unit', 'comes', 'earpad', 'recommend'],
#  [],
#  ['gotten', 'risk', 'buying', 'built', 'quality'],
#  ['case', 'small', 'difficult'],
#  ['restored', 'phone', 'like', 'new'],
#  ['recommend', 'purchasing', 'jabra', 'series', 'works', 'flawlessly', 'moto'],
#  ['searched', 'best'],
#  ['does'],
#  ['happy'],
#  ['screen',
#   'size',
#   'key',
#   'pad',
#   'lit',
#   'camera',
#   'quality',
#   'excellent',
#   'camera'],
#  ['really', 'bad', 'say'],
#  ['glad', 'product', 'amazon', 'hard', 'high'],
#  ['portable'],
#  ['colleague', 'great', 'little', 'performance'],
#  ['fully',
#   'charged',
#   'went',
#   'bed',
#   'turned',
#   'blue',
#   'tooth',
#   'noticed',
#   '20',
#   'left'],
#  ['problems', 'phone', 'reading', 'memory', 'card', 'turn'],
#  ['good', 'wearing', 'hat'],
#  ['timely', 'shipment', 'quality'],
#  ['nice', 'solid'],
#  ['fits', 'surefire', 'gx2'],
#  ['horrible'],
#  ['bt50', 'battery'],
#  ['recommend'],
#  ['software', 'work'],
#  [],
#  ['poor', 'voice'],
#  ['battery', 'works'],
#  ['buyers', 'remorse'],
#  ['disappointed'],
#  ['inexcusable', 'probably', 'returning', 'phone', 'changing'],
#  ['looks', 'great'],
#  ['tmobile', 'service', 'years', 'pretty', 'happy'],
#  ['update', 'procedure', 'difficult'],
#  ['hate', 'goes'],
#  ['great', 'software'],
#  ['delivery'],
#  ['easy'],
#  ['uncomfortable', 'use', 'lg', 'vx9900'],
#  ['volume', 'switch', 'rocketed', 'unit', 'destination'],
#  ['holds',
#   'charge',
#   'long',
#   'reasonably',
#   'comfortable',
#   'conditions',
#   'quality',
#   'sound'],
#  ['like', 'return'],
#  ['keyboard', 'really', 'worthwhile', 'usefulness', 'sturdy', 'expect'],
#  ['difficult', 'understand', 'pricing', 'plans'],
#  ['charging', 'batteries', 'work'],
#  ['regret'],
#  ['love'],
#  [],
#  ['user'],
#  ['unfortunately',
#   'ability',
#   'actually',
#   'know',
#   'receiving',
#   'important',
#   'feature',
#   'phone',
#   'pitiful'],
#  ['exchanged'],
#  ['results', 'phone', 'stuck', 'max', 'volume'],
#  ['pda'],
#  ['super', 'charged', 'use', 'small', 'hybrid', 'excels'],
#  ['definitely', 'recommend', 'jabra', 'bt250v', 'looking', 'clarity', 'great'],
#  ['verizon', 'years', 'ago', 'really', 'liked'],
#  ['pretty', 'piece'],
#  ['plug', 'wrong'],
#  ['works'],
#  ['save', 'item', '11', 'months'],
#  ['bad'],
#  ['im'],
#  ['bose', 'noise', 'cancelling', 'important', 'nyc'],
#  ['battery', 'excellent'],
#  ['defective'],
#  ['given', 'star'],
#  ['wear', 'glasses', 'fits', 'fine'],
#  ['sound', 'quality', 'device', 'really', 'quiet', 'hear'],
#  ['recommend', 'item'],
#  ['holster', 'arrived', 'did', 'match', 'photo'],
#  ['problems'],
#  ['earlier', 'review', 'plug', 'charger'],
#  ['frog', 'phone', 'charm', 'adorable', 'eye'],
#  ['know', 'pushed', 'hard', 'right', 'number', 'times', 'function', 'want'],
#  ['sound', 'clear', 'people', 'talk', 'amazed', 'quality'],
#  ['got',
#   'aluminum',
#   'case',
#   'new',
#   'palm',
#   'vx',
#   'worked',
#   'really',
#   'protected',
#   'handheld',
#   'perfectly'],
#  ['good'],
#  ['mobile', 'phone', 'tools'],
#  ['impressed', 'job', 'motorola', 'did', 'sturdiness'],
#  ['received', 'orders', 'shipping', 'good', 'working', 'order', 'excited'],
#  ['phone', 'sturdy'],
#  ['impressed', 'recommend', 'item'],
#  ['complaint', 'standard', 'sound', 'volume', 'little', 'low', 'turned'],
#  ['thanks', 'amazon', 'having', 'things', 'need', 'good'],
#  ['ended', 'sliding', 'edge', 'pants', 'pockets'],
#  ['store', 'bought', 'new', 'nokia', 'phone', 'working'],
#  ['works'],
#  ['really'],
#  ['switch'],
#  ['noise', 'shield'],
#  ['real'],
#  ['razr', 'battery', 'good'],
#  ['good', 'work'],
#  ['refuse', 'refund'],
#  ['unfortunately',
#   'easy',
#   'accidentally',
#   'activate',
#   'buttons',
#   'accidentally',
#   'touch',
#   'phone',
#   'face'],
#  ['basically', 'threw', 'money', 'window'],
#  ['great', 'case'],
#  ['took', 'drop', 'inches', 'kitchen', 'counter', 'impressed'],
#  ['bluetooth',
#   'range',
#   'good',
#   'days',
#   'ago',
#   'left',
#   'phone',
#   'got',
#   'carried',
#   'conversation'],
#  ['impressive', 'practical', 'setup', 'ample', 'storage'],
#  ['eargels',
#   'channel',
#   'sound',
#   'directly',
#   'ear',
#   'increase',
#   'sound',
#   'volume'],
#  ['new', 'ones', 'quite', 'worked'],
#  ['glad', 'purchased'],
#  ['missed', 'numerous', 'calls'],
#  ['phone', 'people', 'hear', 'use'],
#  ['buy'],
#  ['stuff', 'does', 'work'],
#  ['happier', 'new'],
#  ['worst', 'software', 'zero', 'stars'],
#  ['trying', 'make', 'exercise'],
#  ['case', 'flimsy', 'piece', 'plastic', 'protection'],
#  ['jabra', 'earset', 'happy', 'sound', 'especially'],
#  ['love', 'really', 'pretty', 'good'],
#  ['thank', 'great'],
#  ['total'],
#  ['seller', 'understanding', 'definitely', 'buy'],
#  ['wirefly', 'contact', 'inform'],
#  [],
#  ['great', 'product'],
#  ['purchased', 'family', 'enjoy', 'clarity', 'ease', 'use'],
#  ['virgin', 'wireless', 'rocks', 'does', 'cheap', 'little'],
#  ['just', 'buy'],
#  ['low', 'quality', 'casing', 'insert', 'poorly', 'super', 'glued', 'slid'],
#  ['dont', 'waste'],
#  ['quite', 'satisfied'],
#  ['looking', 'good', 'quality', 'motorola', 'headset'],
#  ['plantronincs', 'continues', 'use', 'flawed', 'charger'],
#  ['disapointing'],
#  ['cumbersome'],
#  ['great', 'new', 'packaged', 'nice', 'works', 'problems', 'came', 'time'],
#  ['great'],
#  ['piece'],
#  ['experience', 'fourth', 'bluetooth', 'comfortable', 'jabra'],
#  ['fixes'],
#  ['worst'],
#  ['happy'],
#  ['trouble', 'accessing', 'downloading', 'ringtones', 'performing'],
#  ['barely', 'hear', 'constantly', 'saying'],
#  ['battery', 'life', 'highly'],
#  ['company'],
#  ['does', 'description', 'said'],
#  ['happening', 'forced', 'stop', 'using'],
#  ['works', 'great', 'car', 'especially', 'plug', 'adapters'],
#  ['verizon',
#   'tech',
#   'support',
#   'walked',
#   'worked',
#   'ended',
#   'having',
#   'hard',
#   'wiping'],
#  ['voice', 'signal', 'dropped'],
#  ['plays', 'louder', 'speaker', 'price', 'low', 'think', 'quality'],
#  ['better'],
#  ['feels',
#   'poorly',
#   'menus',
#   'difficult',
#   'buttons',
#   'recessed',
#   'difficult',
#   'push'],
#  ['battery', 'holding'],
#  ['difficult', 'recommend', 'avoiding'],
#  ['used', 'easy', 'hear'],
#  ['got', 'car', 'charger', 'week', 'charger', 'went', 'plug', 'started'],
#  ['sprint', 'terrible', 'customer'],
#  ['linked', 'phone'],
#  [],
#  ['easy'],
#  ['better'],
#  ['possesed'],
#  ['piece'],
#  ['pretty', 'good'],
#  ['great'],
#  ['price', 'excellent', 'highly'],
#  ['research', 'development', 'division', 'obviously', 'knows'],
#  ['real', 'killer', 'course'],
#  ['phones', 'working', 'just', 'fine'],
#  ['happy'],
#  ['poor'],
#  [],
#  ['recommend', 'phone', 'new'],
#  ['sprint', 'charges'],
#  ['feel', 'look', 'just'],
#  ['fits', 'ear', 'comfortable'],
#  ['work', 'europe'],
#  ['clipping', 'belt', 'deffinitely', 'make', 'feel', 'like', '50'],
#  ['like',
#   'design',
#   'look',
#   'jabra',
#   'behing',
#   'ear',
#   'headsets',
#   '5020',
#   'pretty',
#   'comfortible',
#   'wear',
#   '24',
#   'hours',
#   'day',
#   'pain'],
#  ['amazed',
#   'quick',
#   'arrival',
#   'original',
#   'lg',
#   'cell',
#   'phone',
#   'batteries',
#   'fraction'],
#  ['worst', 'phone', 'crappy', 'samsung', 'worst'],
#  ['charger', 'worked', 'week', 'completely', 'stopped', 'charging'],
#  ['poor'],
#  ['needed', 'better'],
#  ['need',
#   'hands',
#   'operate',
#   'software',
#   'interface',
#   'decade',
#   'old',
#   'compete',
#   'new',
#   'software'],
#  ['worked',
#   'paired',
#   'treo',
#   '700w',
#   'skype',
#   'headset',
#   'pc',
#   'usb',
#   'bluetooth'],
#  ['steer', 'clear', 'product', 'genuine', 'palm', 'replacementr', 'come'],
#  ['buy', 'buyit', 'sucks'],
#  ['great', 'sure', 'beats', 'using'],
#  ['seriously', 'believe', 'worth', 'steep', 'price'],
#  ['cases', 'tried', 'normally', 'fall', 'apart', 'months', 'long'],
#  ['dissapointing'],
#  ['make', 'mistake', 'did', 'buy'],
#  ['phone', 'worst'],
#  ['case', 'extra', 'originally', 'later', 'discarded', 'scratched'],
#  ['recommend', 'igo', 'different', 'brand', 'cell', 'players'],
#  ['bother'],
#  ['posted', 'detailed', 'comments', 'grey', 'black', 'red', 'great'],
#  ['did', 'problem', 'item', 'order'],
#  ['pay'],
#  ['did',
#   'software',
#   'great',
#   'job',
#   'make',
#   'ringtones',
#   'form',
#   'existing',
#   'cds',
#   'internet'],
#  ['im', 'surprised', 'good', 'quality', 'car', 'charger', 'reviews'],
#  [],
#  ['bt',
#   'headsets',
#   'currently',
#   'good',
#   'real',
#   'time',
#   'games',
#   'like',
#   'shooters',
#   'audio',
#   'delay',
#   'messes'],
#  ['used', 'bitpim', 'free', 'program', 'transfer', 'data', 'price', 'cable'],
#  ['disappointing', 'accessory', 'good'],
#  ['performed', 'awful', 'tinny', 'incoming', 'sound', 'severe', 'echo', 'end'],
#  [],
#  ['obviously', 'terrible', 'customer', 'pay'],
#  ['overly', 'expensive', 'operate', 'sound', 'better'],
#  ['contacted', 'company', 'told', 'unit', 'produce', 'receipt'],
#  ['linksys', 'way', 'exchange', 'bad', 'phone', 'refurb', 'unit'],
#  ['phone', 'sturdy', 'nokia', 'bar', 'phones'],
#  ['great'],
#  ['placed', 'treo', 'lot', 'extra', 'room'],
#  [],
#  ['battery'],
#  ['product', 'easy', 'set'],
#  ['earpiece', 'large', 'keeps', 'falling'],
#  ['utter', 'sound', 'quality'],
#  ['charger', 'arrived', 'promised', 'did'],
#  ['ear', 'loop', 'tiny', 'sound'],
#  ['times', 'spring', 'latch', 'broke', 'use', 'longer'],
#  ['handsfree',
#   'works',
#   'car',
#   'tries',
#   'download',
#   'address',
#   'treo',
#   'rate',
#   'device'],
#  ['talk', 'useless', 'customer'],
#  ['felt', 'light'],
#  ['does', 'fit', 'palm', 'tungsten', 'e2', 'broke', 'time', 'tried', 'plug'],
#  ['happy', 'good', 'quality', 'low'],
#  ['love', 'look', 'feel', 'samsung'],
#  ['sharp', 'blue', 'nice'],
#  ['does'],
#  ['recommend'],
#  ['nice'],
#  ['looks', 'good', 'case', 'huge'],
#  ['jawbone', 'going', 'replace'],
#  ['setup', 'went'],
#  ['extremely', 'slow', 'takes', 'forever'],
#  ['study', 'interested', 'industrial'],
#  ['thing', 'happened', 'tracking'],
#  ['easy', 'access', 'phone', 'detachable', 'belt'],
#  ['continue', 'pairing', 'periodically', 'kept'],
#  ['upload', 'ringtones'],
#  ['bluetooth',
#   'does',
#   'phone',
#   'locks',
#   'screens',
#   'just',
#   'flash',
#   'just',
#   'makes',
#   'calls',
#   'randomly',
#   'pocket'],
#  ['truly'],
#  ['works', 'fine', 'motorola', '325', 'lot', 'better', 'battery'],
#  ['volume', 'ringer', 'real', 'good', 'choices'],
#  ['tones'],
#  ['camera', 'color', 'balance'],
#  ['product', 'clearly', 'ready', 'prime', 'care', 'cool', 'tell', 'coming'],
#  ['love', 'ringtones'],
#  ['chinese', 'forgeries'],
#  ['easy', 'pair', 'samsung'],
#  ['instructions', 'explain', 'microphone', 'jack'],
#  ['advise', 'purchase', 'item', 'worked'],
#  ['bad', 'pay', 'month'],
#  ['works'],
#  ['nokia', 'usb', 'cable', 'did', 'work'],
#  ['clear', 'crisp'],
#  ['use', 'smallest', 'earpieces', 'stays', 'pretty'],
#  ['biggest', 'complaint', 'battery', 'drains'],
#  ['design', 'ergonomic', 'theory', 'stand', 'having'],
#  ['buy', 'want', 'use'],
#  ['phone', 'great', 'pictures', 'video'],
#  ['make', 'look'],
#  ['ears', 'background', 'distracting'],
#  ['comfortable', 'fit', 'need', 'headset', 'comfortable', 'hour', 'entire'],
#  ['phone', 'accept', 'cbr', 'preferably', 'ripped', 'windows', 'media'],
#  ['beat', 'price'],
#  ['comes',
#   'strong',
#   'light',
#   'use',
#   'light',
#   'camera',
#   'flash',
#   'sos',
#   'signals'],
#  ['lightweight', 'works'],
#  ['just'],
#  ['love', 'cable', 'allows', 'connect', 'device'],
#  ['near', 'hear'],
#  ['cool', 'cases', 'just', 'open', 'allowing', 'screen', 'scratched'],
#  ['bought', 'phone', 'replacement', 'startac', 'regretted'],
#  ['appears', 'actually', 'outperform', 'original', 'battery', 'china', 'came'],
#  ['store', 'phone', 'numbers'],
#  ['lasts', '3o', 'actually', 'try', 'use', 'wife', 'phone'],
#  ['poor'],
#  ['jabra', 'ear', 'gels'],
#  ['worth'],
#  ['phone', 'crashed', 'completely'],
#  ['quit', 'working', 'used', '18', 'just', 'purchased', 'best', 'headset'],
#  ['unfortunately',
#   'recharge',
#   'iphone',
#   'despite',
#   'connecting',
#   'multiple',
#   'power',
#   'sources',
#   'external',
#   'wall'],
#  ['great'],
#  ['simply',
#   'want',
#   'small',
#   'flip',
#   'phone',
#   'look',
#   'extra',
#   'bells',
#   'whistles'],
#  ['good', 'works', 'fine', 'power', 'wall'],
#  ['phone', 'slide', 'car', 'grip', 'prevents', 'phone', 'slipping'],
#  ['simply', 'best', 'bluetooth', 'headset', 'sound'],
#  ['think', 'plan', 'sure', 'moto', 'phone'],
#  ['span', 'people', 'exclaim', 'new', 'phone'],
#  ['used', 'corded', 'headsets', 'freedom', 'wireless'],
#  ['case', 'passed', 'year', 'mark', 'shows', 'signs'],
#  ['leather', 'nice', 'fit', 'cut', 'face', 'good'],
#  ['need', 'ask'],
#  ['receiving', 'using', 'product', 'just', 'days'],
#  ['product', 'makes', 'working', 'lot', 'easier', 'copier', 'waiting', 'hold'],
#  ['sizes', 'sent', 'headset', 'stay'],
#  ['best', 'customer', 'service'],
#  ['arrived', 'quickly', 'expensive'],
#  ['tried', 'units', 'failed', 'pros'],
#  ['provides', 'good', 'protection', 'looks'],
#  ['krussel'],
#  ['tracfonewebsite', 'user', 'friendly', 'makes', 'easy'],
#  ['design'],
#  ['great', 'reception'],
#  ['highly', 'recommend'],
#  ['use', 'unit', 'good'],
#  ['dit', 'work', 'time', 'nokia'],
#  ['bought', 'mainly', 'broke', 'soon'],
#  ['like', 'loud', 'buzzing', 'override', 'phone'],
#  ['fantastic', 'buy', 'phone'],
#  ['stay', 'away'],
#  ['blueant', 'supertooth', 'phone', 'speaker'],
#  ['does'],
#  ['item',
#   'arrived',
#   'quickly',
#   'works',
#   'great',
#   'metro',
#   'pcs',
#   'samsung',
#   'slider',
#   'phone',
#   'sony',
#   'premium',
#   'sound',
#   'ear'],
#  ['plenty',
#   'battery',
#   'confortable',
#   'wear',
#   'somewhat',
#   'extended',
#   'periods'],
#  [],
#  ['blue', 'ant', 'easy'],
#  ['cheap', 'hey', 'pleasantly', 'suprised', 'given', 'low', 'cost'],
#  ['camera', 'phone', 'used', 'dustpan', 'using', 'disposable'],
#  ['days', 'later', 'puff', 'smoke', 'came', 'phone'],
#  ['convenient', 'simple', 'use', 'gets', 'job', 'makes', 'car', 'ride'],
#  ['nano', 'stated', 'son'],
#  ['sound', 'quality', 'excellent'],
#  ['best', 'headset'],
#  [],
#  ['years', 'carries', 'highest', 'quality', 'screen', 'protector'],
#  ['just'],
#  ['particular', 'model', 'work', 'motorola'],
#  ['wont', 'work', 'right', 'atleast'],
#  ['addition', 'feels', 'looks', 'phone', 'lightweight', 'cheap'],
#  ['problems', 'money', 'cingular', 'support'],
#  ['really', 'wanted', 'plantronics', '510', 'right', 'issues', 'good'],
#  ['great'],
#  ['crisp'],
#  ['charge', 'kept', 'going', 'dead', '12'],
#  ['cheap', 'creaks', 'like', 'old', 'wooden'],
#  ['absolutely', 'horrible', 'reception', 'phones'],
#  ['reception', 'generally'],
#  ['excellent', 'battery', 'life', 'inconspicuous'],
#  ['great'],
#  ['highly', 'recommend'],
#  [],
#  ['great'],
#  ['phone', 'got', 'year', 'slowly', 'breaking', 'despite', 'care'],
#  ['sorry'],
#  ['bought',
#   'hoping',
#   'make',
#   'bluetooth',
#   'headset',
#   'fit',
#   'better',
#   'things',
#   'impossible'],
#  ['treo', 'refused', 'replace', 'forced', 'buy', 'phone', 'kind', 'upgrade'],
#  [],
#  ['think', 'hold', 'securly'],
#  ['allows', 'possibility', 'double', 'booking', 'date', 'time'],
#  ['work', 'weeks'],
#  ['simple', 'use', 'like'],
#  ['great',
#   'tool',
#   'data',
#   'sure',
#   'use',
#   'activesync',
#   'optimal',
#   'data',
#   'synchronization'],
#  ['use', 'case', 'smell'],
#  [],
#  ['cases', 'order'],
#  ['great'],
#  ['bought', 'battery', 'coupon', 'amazon', 'happy'],
#  ['internet', 'access', 'rare', 'instance'],
#  ['perfect'],
#  ['star'],
#  ['good',
#   'quality',
#   'bought',
#   'bought',
#   'cheapy',
#   'big',
#   'lots',
#   'sounded',
#   'awful',
#   'people',
#   'end',
#   'hear'],
#  [],
#  ['tried',
#   'talking',
#   'real',
#   'loud',
#   'shouting',
#   'telephone',
#   'gets',
#   'old',
#   'told'],
#  ['good', 'works'],
#  ['price', 'great'],
#  ['great'],
#  ['completely'],
#  ['yes', 'shiny', 'love'],
#  ['does'],
#  ['thought', 'grtting', 'good', 'deal', 'plugged', 'phone'],
#  ['reception', 'headset'],
#  ['thumbs', 'seller'],
#  ['verizon',
#   'lg',
#   'phone',
#   'work',
#   'good',
#   'reception',
#   'range',
#   'exceeds',
#   '20',
#   'feet',
#   'line'],
#  ['improper', 'return'],
#  ['works'],
#  ['battery', 'quite'],
#  ['jabra', 'eargels', 'fit', 'ears'],
#  ['battery'],
#  ['checked', 'feature', 'really'],
#  ['product', 'exactly'],
#  ['gets', 'signal', 'verizon', 'phones'],
#  [],
#  ['recommend'],
#  ['plan', 'ordering'],
#  ['camera', 'cool', 'effects', 'play', 'video', 'decent'],
#  ['satisfied', 'cell', 'phone', 'day'],
#  ['getting', 'better', 'better', 'numerous', 'palms'],
#  ['awkward', 'use'],
#  ['shipping', 'time'],
#  ['good'],
#  ['good'],
#  [],
#  ['really', 'good'],
#  ['unfortunately', 'did'],
#  ['broke', 'months'],
#  ['dont', 'buy'],
#  ['father', 'battery'],
#  ['ear', 'pads', 'come', 'easily', 'week', 'lost'],
#  ['calls',
#   'phone',
#   'comes',
#   'screen',
#   'goes',
#   'black',
#   'worst',
#   'stops',
#   'ringing'],
#  ['horrible'],
#  ['like', 'nokia'],
#  ['reaching', 'row', 'send', 'end', 'keys', 'expect'],
#  ['bought', 'nokia', 'cell', 'phone', 'weeks', 'ago'],
#  ['long', 'bad', 'customer', 'service', 'experience'],
#  ['disappointing', 'thing'],
#  ['car', 'accept'],
#  ['product',
#   'does',
#   'charging',
#   'current',
#   'charge',
#   'cellphones',
#   'planning',
#   'use'],
#  ['says'],
#  ['stay', 'away'],
#  ['used'],
#  ['unreliable', 'service'],
#  ['good'],
#  ['bought'],
#  ['looks'],
#  ['excellent', 'especially', 'paired'],
#  ['read', 'reviews', 'problem'],
#  ['products', 'cover', 'important', 'light', 'sensor', 'ear'],
#  ['comfortable'],
#  ['just', 'does'],
#  ['poor'],
#  [],
#  ['battery', 'drops', 'starts', 'letting', 'know'],
#  ['terrible', 'waste'],
#  ['time', 'buying'],
#  ['waste'],
#  ['far', 'worked', 'like'],
#  [],
#  ['best',
#   'download',
#   'pictures',
#   'laptop',
#   'using',
#   'send',
#   'pictures',
#   'laptop'],
#  ['recommend'],
#  ['choice', 'headset', 'good', 'good', 'noise'],
#  ['nice', 'feels', 'good'],
#  ['item', 'received'],
#  ['just', 'really', 'probably', 'best', 'bt', 'headset'],
#  ['works'],
#  ['received', 'headset', 'good', 'time', 'happy'],
#  ['pleased', 'replace', 'travled', 'swivel', 'holster', 'blackberry'],
#  ['sister', 'loves'],
#  ['good'],
#  ['far', 'worst', 'purchase'],
#  ['excellent'],
#  [],
#  ['does', 'work', 'listening', 'music', 'cingular'],
#  ['completely', 'holding', 'keeping', 'iphone'],
#  ['bottowm', 'cheap', 'gimmick'],
#  ['having', 'trouble'],
#  ['good', 'thing', 'fits', 'comfortably', 'small'],
#  ['warning'],
#  ['pairing', 'happier'],
#  ['battery', 'connection', 'broken', 'device', 'turned'],
#  ['want', 'clip', 'going', 'causing'],
#  ['best', 'headset'],
#  ['trust', 'website', 'expect', 'helpful'],
#  ['say',
#   'plantronics',
#   '510',
#   'maintains',
#   'flawless',
#   'connection',
#   'cell',
#   'static',
#   'normal'],
#  ['speaker', 'low', 'quality', 'making', 'ring', 'tones', 'sound'],
#  ['fits', 'came', 'sizes', 'earbud'],
#  ['excellent', 'product'],
#  ['bad'],
#  ['product', 'high', 'quality', 'chinese'],
#  ['quite', 'comfortable'],
#  ['great'],
#  ['buy', 'product'],
#  ['product'],
#  ['pairing',
#   'devices',
#   'easy',
#   'barely',
#   'took',
#   'couple',
#   'minutes',
#   'started',
#   'making',
#   'calls',
#   'voice',
#   'dialing'],
#  ['utterly', 'confusing', 'caused', 'lose', 'couple', 'important'],
#  ['terrible', 'phone'],
#  ['cutouts', 'buttons', 'placed'],
#  ['love', 'able', 'use', 'headset'],
#  ['problem', 'ear', 'loops', 'weak', 'material', 'break'],
#  ['nearly', 'good', 'looking', 'amazon', 'picture', 'makes'],
#  ['despite',
#   'case',
#   'exceptional',
#   'quality',
#   'worth',
#   'additional',
#   'costs',
#   'owning',
#   'official',
#   'oem'],
#  ['stupid'],
#  ['hear', 'driving', 'usually', 'loudest'],
#  ['seller', 'shipped', 'quickly', 'cheaper'],
#  ['good'],
#  ['bought', '10', 'saved', 'alot'],
#  ['cuts', 'makes', 'beep', 'beep', 'beep', 'sound', 'says', 'signal'],
#  ['figure'],
#  ['phone',
#   'sounded',
#   'ok',
#   'great',
#   'phone',
#   'totally',
#   'understand',
#   'word',
#   'said'],
#  ['battery', 'phone', 'restart'],
#  ['managed', 'bend', 'leaf', 'spring', 'metal', 'stress', 'break'],
#  ['leopard', 'print', 'wonderfully'],
#  ['works'],
#  ['floppy', 'piece'],
#  ['better', 'hard', 'plastic'],
#  ['new'],
#  ['happy'],
#  ['cool'],
#  ['works'],
#  ['motorola', 'finally', 'got', 'voice', 'quality', 'bluetooth', 'headset'],
#  ['looses', 'connection', 'phone', 'couple', 'feet'],
#  ['really', 'recommend'],
#  ['makes', 'easier', 'bluetooth', 'wearing'],
#  ['said'],
#  ['got'],
#  ['pair', 'headphones', 'worst'],
#  ['drain', 'weak'],
#  ['does', 'charge', 'cingular', '8525'],
#  ['extra', 'minutes', 'carry', 'cut'],
#  ['fliptop',
#   'started',
#   'loose',
#   'wobbly',
#   'eventually',
#   'screen',
#   'went',
#   'black',
#   'receive',
#   'place'],
#  ['kept', 'catching', 'cable', 'seat', 'pull', 'phone', 'turn'],
#  ['headset', 'fulfills', 'requirements', 'happy'],
#  ['logitech', 'bluetooth', 'headset'],
#  ['like', 'fact', 'rests', 'lightly'],
#  ['lot', 'websites', 'rating', 'good', 'phone'],
#  ['tried', 'cables', 'computer', 'ipod', 'works', 'just'],
#  ['mic', 'volume', 'quite'],
#  ['returning'],
#  ['does', 'maintain', 'connection', 'computer'],
#  ['easy', 'turn', 'car', 'volume', 'controls', 'quite'],
#  ['year', 'christmas', 'bought', 'rest'],
#  ['easy', 'install', 'clear'],
#  ['nice'],
#  ['purchase', 'different'],
#  ['joy'],
#  ['disappointed'],
#  ['satisifed'],
#  ['charge'],
#  ['phone', 'just', 'bought', 's710a', 'say'],
#  ['buttons'],
#  ['just', 'reading', 'specs', 'makes', 'say'],
#  ['love', 'great'],
#  ['really', 'like', 'product', 'motorola', 'allot', 'clearer', 'ear', 'piece'],
#  ['keypads', 'tinny', 'reach', 'wrong'],
#  ['exchanged', 'sony', 'ericson', 'z500a', 'pretty', 'happy'],
#  ['impressed', 'price'],
#  ['makes', 'easier', 'hold'],
#  ['use',
#   'product',
#   'motor',
#   'control',
#   'center',
#   'lot',
#   'high',
#   'voltage',
#   'humming',
#   'works'],
#  ['pretty'],
#  ['make', 'calls', 'certain'],
#  ['girl', 'complain', 'time', 'phone', 'wake', 'like', 'normal', 'phone'],
#  ['beautiful', 'styling'],
#  ['company', 'charge', 'restocking', 'fee', 'given', 'refund'],
#  ['trying', 'return'],
#  ['plugged', 'darn', 'thing'],
#  ['excellent'],
#  ['earbud', 'piece', 'breaks'],
#  ['lousy'],
#  ['phone', 'tries', 'hard', 'fails', 'ability'],
#  ['best', 'charger', 'seen', 'market'],
#  ['sweetest'],
#  ['charger', 'work'],
#  ['fits',
#   'securely',
#   'ear',
#   'hook',
#   'does',
#   'need',
#   'used',
#   'sound',
#   'better',
#   'directed',
#   'ear'],
#  [],
#  ['echo', 'unsatisfactory'],
#  ['videos', 'time', 'quality'],
#  ['waste'],
#  ['going', 'negatively', 'review'],
#  ['adapter', 'does', 'provide', 'charging'],
#  ['hype', 'phone', 'assumed'],
#  ['pictures', 'case', 'lense'],
#  ['phone', 'falls'],
#  ['people', 'hear'],
#  ['text', 'messaging', 'feature', 'really', 'tricky'],
#  ['really', 'disappointed', 'charger'],
#  ['painful'],
#  ['lasted', 'day', 'blew'],
#  [],
#  ['kind', 'flops'],
#  ['screen', 'does', 'smudged', 'easily', 'touches', 'ear'],
#  ['piece', 'lose', 'calls'],
#  ['item', 'does', 'match'],
#  ['thing', 'disappoint', 'infra', 'red', 'port'],
#  ['answer', 'calls', 'worked']]

# %%
#Time to drop it back into my model
model_new = Word2Vec(sentences2, size = 100, window = 5, min_count = 5, workers = 4)

# %%
#Run this little thing again
model_new.wv.most_similar(positive = ['great'])

#Ok - that looks much better. So.... what did we learn?
# Out:
# [('makes', 0.27968427538871765),
#  ('talk', 0.27064287662506104),
#  ('works', 0.25068968534469604),
#  ('headsets', 0.24682296812534332),
#  ('purchase', 0.21913033723831177),
#  ('long', 0.18717731535434723),
#  ('gets', 0.18573476374149323),
#  ('did', 0.18376567959785461),
#  ('fits', 0.1788528561592102),
#  ('phones', 0.1679503619670868)]

# %% [markdown]
# ## Preprocessing
#
# Let's look at using pre-processing to my information before I kick it into once of these models - in this case LDA

# %%
# Not the best method so let's use some of the pre-processing tools we learned last class to setup a cleaning function.
# You'll need to make sure you have some resources downloaded. Run the below then comment it out for the future
#import nltk
#nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\slongstreet\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# What am I grabbing? Stopwords, lemmatizer and string (to deal with punctuation)
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

# %%
# I hate typing the whole thing and I like to set these against key values like with my stopwords
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

# %%
# Time to package these into a function
def clean(doc):
    #Lets create a stopword free list of lowercase letters that do not include my stopwords
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop]) 
    #Now take that list and remove any punctuation
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    #Now to lemmatize each word so I have a fully cleaned list
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# %%
#I'm creating doc_clean to received my cleaned list then saying I want individual words for each document in df.review
doc_clean = [clean(doc).split() for doc in df.review]

# %%
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our courpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)

# %%
# Showing Results
ldamodel.print_topics(num_topics=3, num_words=5)
# Out:
# [(0,
#   '0.036*"phone" + 0.035*"great" + 0.026*"work" + 0.019*"product" + 0.018*"good"'),
#  (1,
#   '0.017*"phone" + 0.014*"headset" + 0.012*"charger" + 0.011*"it" + 0.009*"im"'),
#  (2,
#   '0.018*"phone" + 0.012*"one" + 0.012*"ear" + 0.011*"headset" + 0.011*"ive"')]

# %% [markdown]
# ## What about Word2vec?

# %%
# Can we use any of the word we've done so far? Let's look at doc_clean
doc_clean
# Out:
# [['way', 'plug', 'u', 'unless', 'go', 'converter'],
#  ['good', 'case', 'excellent', 'value'],
#  ['great', 'jawbone'],
#  ['tied',
#   'charger',
#   'conversation',
#   'lasting',
#   '45',
#   'minutesmajor',
#   'problem'],
#  ['mic', 'great'],
#  ['jiggle', 'plug', 'get', 'line', 'right', 'get', 'decent', 'volume'],
#  ['several',
#   'dozen',
#   'several',
#   'hundred',
#   'contact',
#   'imagine',
#   'fun',
#   'sending',
#   'one',
#   'one'],
#  ['razr', 'owneryou', 'must', 'this'],
#  ['needle', 'say', 'wasted', 'money'],
#  ['waste', 'money', 'time'],
#  ['sound', 'quality', 'great'],
#  ['impressed', 'going', 'original', 'battery', 'extended', 'battery'],
#  ['two',
#   'seperated',
#   'mere',
#   '5',
#   'ft',
#   'started',
#   'notice',
#   'excessive',
#   'static',
#   'garbled',
#   'sound',
#   'headset'],
#  ['good', 'quality', 'though'],
#  ['design', 'odd', 'ear', 'clip', 'comfortable', 'all'],
#  ['highly', 'recommend', 'one', 'blue', 'tooth', 'phone'],
#  ['advise', 'everyone', 'fooled'],
#  ['far', 'good'],
#  ['work', 'great'],
#  ['click',
#   'place',
#   'way',
#   'make',
#   'wonder',
#   'long',
#   'mechanism',
#   'would',
#   'last'],
#  ['went',
#   'motorolas',
#   'website',
#   'followed',
#   'direction',
#   'could',
#   'get',
#   'pair',
#   'again'],
#  ['bought', 'use', 'kindle', 'fire', 'absolutely', 'loved', 'it'],
#  ['commercial', 'misleading'],
#  ['yet',
#   'run',
#   'new',
#   'battery',
#   'two',
#   'bar',
#   'thats',
#   'three',
#   'day',
#   'without',
#   'charging'],
#  ['bought', 'mother', 'problem', 'battery'],
#  ['great', 'pocket', 'pc', 'phone', 'combination'],
#  ['ive',
#   'owned',
#   'phone',
#   '7',
#   'month',
#   'say',
#   'best',
#   'mobile',
#   'phone',
#   'ive',
#   'had'],
#  ['think', 'instruction', 'provided', 'helpful', 'me'],
#  ['people', 'couldnt', 'hear', 'talk', 'pull', 'earphone', 'talk', 'phone'],
#  ['hold', 'charge'],
#  ['simple', 'little', 'phone', 'use', 'breakage', 'unacceptible'],
#  ['product', 'ideal', 'people', 'like', 'whose', 'ear', 'sensitive'],
#  ['unusable', 'moving', 'car', 'freeway', 'speed'],
#  ['two', 'year', 'left', 'contract', 'hate', 'phone'],
#  ['car',
#   'charger',
#   'well',
#   'ac',
#   'charger',
#   'included',
#   'make',
#   'sure',
#   'never',
#   'run',
#   'juicehighy',
#   'recommended'],
#  ['need',
#   'least',
#   '3',
#   'min',
#   'get',
#   'phone',
#   'book',
#   'time',
#   'first',
#   'turn',
#   'phonebattery',
#   'life',
#   'short'],
#  ['kept', 'well'],
#  ['poor', 'talk', 'time', 'performance'],
#  ['case', 'great', 'work', 'fine', '680'],
#  ['worthless', 'product'],
#  ['great',
#   'camera',
#   'thats',
#   '2mp',
#   'pic',
#   'nice',
#   'clear',
#   'great',
#   'picture',
#   'quality'],
#  ['impressed', 'product'],
#  ['nice', 'headset', 'priced', 'right'],
#  ['hear', 'garbage', 'audio'],
#  ['excellent', 'bluetooth', 'headset'],
#  ['feature', 'want'],
#  ['right', 'mind', 'gonna', 'buy', 'battery'],
#  ['arguing',
#   'verizon',
#   'regarding',
#   'dropped',
#   'call',
#   'returned',
#   'phone',
#   'two',
#   'day'],
#  ['case', 'seems', 'well', 'made'],
#  ['disappointed', 'battery'],
#  ['loud', 'enough', 'turn', 'like', 'should'],
#  ['good', 'protection', 'make', 'phone', 'bulky'],
#  ['usable',
#   'keyboard',
#   'actually',
#   'turn',
#   'pda',
#   'realworld',
#   'useful',
#   'machine',
#   'instead',
#   'neat',
#   'gadget'],
#  ['phone', 'pretty', 'sturdy', 'ive', 'never', 'large', 'problem', 'it'],
#  ['love', 'thing'],
#  ['everything', 'fine', 'reasonable', 'price', 'ie'],
#  ['disappointed'],
#  ['even',
#   'dropped',
#   'phone',
#   'stream',
#   'submerged',
#   '15',
#   'second',
#   'still',
#   'work',
#   'great'],
#  ['happy', '510', 'complaint', 'one', 'regarding', 'sound', 'quality', 'end'],
#  ['button', 'bad'],
#  ['essentially', 'forget', 'microsofts', 'tech', 'support'],
#  ['really',
#   'recommend',
#   'faceplate',
#   'since',
#   'look',
#   'nice',
#   'elegant',
#   'cool'],
#  ['headphone',
#   'great',
#   'find',
#   'think',
#   'perhaps',
#   'best',
#   'purchase',
#   'ive',
#   'made',
#   'last',
#   'several',
#   'year',
#   'seriously'],
#  ['buy', 'different', 'phone', 'this'],
#  ['hold', 'phone', 'particular', 'angle', 'party', 'hear', 'clearly'],
#  ['one',
#   'big',
#   'drawback',
#   'mp3',
#   'player',
#   'button',
#   'phone',
#   'front',
#   'cover',
#   'let',
#   'pause',
#   'skip',
#   'song',
#   'lock',
#   'second'],
#  ['week', 'later', 'activated', 'it', 'suddenly', 'died'],
#  ['feel',
#   'comfortable',
#   'headset',
#   'wear',
#   'glass',
#   'get',
#   'way',
#   'sometimes'],
#  ['great', 'ipod', 'too'],
#  ['device', 'great', 'several', 'situations1'],
#  ['mic', 'work'],
#  ['even',
#   'bmw',
#   '3',
#   'series',
#   'fairly',
#   'quiet',
#   'trouble',
#   'hearing',
#   'person',
#   'saying'],
#  ['great', 'choice'],
#  ['nice', 'docking', 'station', 'home', 'work'],
#  ['beautiful', 'phone'],
#  ['love', 'product'],
#  ['buy', 'd807wrongly', 'advertised', 'd807'],
#  ['great', 'little', 'item'],
#  ['love', 'phone', 'handy', 'lot', 'feature'],
#  ['purchased', 'within', '2', 'day', 'longer', 'working'],
#  ['wear', 'everyday', 'hold', 'well'],
#  ['good', 'bargain'],
#  ['well', 'packaged', 'arrived', 'time', 'work', 'intended'],
#  ['battery', 'run', 'quickly'],
#  ['item', 'worked', 'great', 'broke', '6', 'month', 'use'],
#  ['headset', 'easy', 'use', 'everyone', 'love', 'them'],
#  ['phone', 'work', 'great'],
#  ['construction', 'headset', 'poor'],
#  ['product',
#   'excellent',
#   'work',
#   'better',
#   'verizon',
#   'one',
#   'boy',
#   'cheaper'],
#  ['phone', 'load', 'super'],
#  ['product',
#   'cost',
#   'much',
#   'one',
#   'doe',
#   'expect',
#   'work',
#   'far',
#   'better',
#   'greater',
#   'ease',
#   'thing',
#   'doe'],
#  ['made', 'sturdy'],
#  ['worked', 'great'],
#  ['ear', 'bud', 'play', 'music', 'one', 'ear'],
#  ['dont', 'waste', 'money'],
#  ['order', 'again'],
#  ['plan', 'use', 'car', 'forget', 'it'],
#  ['found', 'product', 'waaay', 'big'],
#  ['best',
#   'ive',
#   'found',
#   'far',
#   'ive',
#   'tried',
#   '2',
#   'bluetooths',
#   'one',
#   'best',
#   'quality',
#   'for',
#   'listener',
#   'well',
#   'ease',
#   'using'],
#  ['im', 'disappointed', 'decision'],
#  ['integrated', 'seamlessly', 'motorola', 'razr', 'phone'],
#  ['buyer', 'beware', 'could', 'flush', 'money', 'right', 'toilet'],
#  ['definitely', 'bargain'],
#  ['price', 'good', 'free', 'shipping', 'good', 'purchase'],
#  ['received',
#   'supposedly',
#   'new',
#   'motorola',
#   '375',
#   'apparently',
#   'match',
#   'phone',
#   'charger'],
#  ['prosgood',
#   'camera',
#   'nice',
#   'picture',
#   'also',
#   'cool',
#   'style',
#   'like',
#   'black',
#   'white',
#   'more'],
#  ['thats',
#   'huge',
#   'design',
#   'flaw',
#   'unless',
#   'im',
#   'using',
#   'correctly',
#   'think',
#   'case'],
#  ['love',
#   '350',
#   'headset',
#   'jabra350',
#   'bluetooth',
#   'headset',
#   'great',
#   'reception',
#   'good',
#   'ear',
#   'piece',
#   'comfortable',
#   'fit'],
#  ['camera',
#   'although',
#   'rated',
#   'impressive',
#   '13',
#   'megapixels',
#   'render',
#   'image',
#   'fall',
#   'well',
#   'expectation',
#   'relatively',
#   'high',
#   'resolution'],
#  ['purcashed', 'car', 'charger', 'work'],
#  ['sound',
#   'quality',
#   'end',
#   'excellent',
#   'use',
#   'headset',
#   'call',
#   'wife',
#   'ask',
#   'wife',
#   'use',
#   'headset',
#   'call',
#   '2'],
#  ['phone', 'slim', 'light', 'display', 'beautiful'],
#  ['little',
#   'geeky',
#   'think',
#   'thats',
#   'sex',
#   'toast',
#   'rock',
#   'ooze',
#   'sex',
#   'right',
#   'battery',
#   'embedded',
#   'sleek',
#   'stylish',
#   'leather',
#   'case'],
#  ['great', 'product', 'fast', 'shipping'],
#  ['absolutely', 'great'],
#  ['keyboard',
#   'nice',
#   'compromise',
#   'full',
#   'qwerty',
#   'basic',
#   'cell',
#   'phone',
#   'number',
#   'keypad'],
#  ['got', 'phone', 'around', 'end', 'may', 'im', 'completely', 'unhappy', 'it'],
#  ['comfortable', 'ear'],
#  ['winner', 'u'],
#  ['setup', 'simpler'],
#  ['ive',
#   'tried',
#   'several',
#   'different',
#   'earpiece',
#   'cell',
#   'phone',
#   'jabra',
#   'one',
#   'first',
#   'one',
#   'ive',
#   'found',
#   'fit',
#   'ear',
#   'comfortably'],
#  ['could', 'get', 'strong', 'enough', 'signal'],
#  ['iam', 'pleased', 'purchase'],
#  ['bad', 'quality'],
#  ['get', 'job', 'done'],
#  ['great', 'audio'],
#  ['basically', 'service', 'bad'],
#  ['work', 'cell', 'phone', 'plug', 'set', 'charger'],
#  ['ive', 'bluetooth', 'week', 'really', 'like', 'it'],
#  ['bt', 'headset', 'disapoinment'],
#  ['small', 'even', 'realize', 'getting', 'used', 'it'],
#  ['accompanied', 'software', 'almost', 'brilliant'],
#  ['headset', 'work', 'great', 'packaged', 'nicely', 'avoid', 'damage'],
#  ['i', 'definitly', 'recommend'],
#  ['buyerbe', 'careful'],
#  ['majority', 'logitech', 'earbud', 'headset', 'failed'],
#  ['good', 'stuff', 'price'],
#  ['headset', 'work', 'peachykeen'],
#  ['house',
#   'getting',
#   'dropped',
#   'coverage',
#   'upstairs',
#   'coverage',
#   'basement'],
#  ['voice', 'recognition', 'tremendous'],
#  ['waste'],
#  ['several',
#   'different',
#   '2',
#   'minute',
#   'call',
#   'experienced',
#   '5',
#   'drop',
#   'area',
#   '5',
#   'bar'],
#  ['happy', 'item'],
#  ['disappointed'],
#  ['phone', 'take', 'forever', 'charge', 'like', '2', '5', 'hour', 'literally'],
#  ['got', 'phone', 'reccomendation', 'relative', 'im', 'glad', 'did'],
#  ['waste', 'time'],
#  ['reception', 'poor'],
#  ['item', 'stated', 'included', 'description', 'included'],
#  ['3', 'month', 'screen', 'went', 'black', 'sudden'],
#  ['hoping', 'more'],
#  ['audio', 'quality', 'poor', 'poor'],
#  ['absolutely',
#   'problem',
#   'headset',
#   'linking',
#   '8530',
#   'blackberry',
#   'curve'],
#  ['know',
#   'sound',
#   'funny',
#   'seemed',
#   'like',
#   'sketchy',
#   'technology',
#   'work',
#   'wellwell',
#   'one',
#   'work',
#   'great'],
#  ['ive', 'bought', '5', 'wired', 'headphone', 'sound', 'better', 'these'],
#  ['phone',
#   'fast',
#   'sending',
#   'kind',
#   'message',
#   'web',
#   'browsing',
#   'significantly',
#   'faster',
#   'previous',
#   'phone',
#   'used'],
#  ['nice', 'quality', 'build', 'unlike', 'cheap', 's', 'there'],
#  ['item', 'fantastic', 'work', 'perfectly'],
#  ['love', 'color'],
#  ['w810i', 'superb'],
#  ['whine', 'internet', 'goesthe', 'use', 'thing', 'le', 'like', 'it'],
#  ['great', 'charger'],
#  ['essentially', 'communication', 'tool', 'communicate'],
#  ['work', 'like', 'charm', 'work', 'one', 'got', 'phone'],
#  ['still',
#   'maintain',
#   'monkey',
#   'make',
#   'headphone',
#   'obviously',
#   'share',
#   'enough',
#   'dna',
#   'copy',
#   'design',
#   'human'],
#  ['great', 'value'],
#  ['work', 'all', 'bougth', 'l7c', 'working'],
#  ['look', 'sharp', 'screen', 'nice', 'clear', 'great', 'graphic'],
#  ['last', 'long'],
#  ['one', 'thing', 'hate', 'mode', 'set', 'button', 'side'],
#  ['excellent', 'service'],
#  ['thank', 'wasting', 'money'],
#  ['bethe', 'audio', 'quality', 'poor'],
#  ['igo', 'charger', 'tip', 'really', 'great'],
#  ['file', 'browser', 'offer', 'option', 'one', 'needshandsfree', 'great'],
#  ['superb', 'phone', 'great', 'network'],
#  ['connected',
#   'wife',
#   'bluetoothmotorola',
#   'hs850',
#   'phone',
#   'worked',
#   'like',
#   'charm',
#   'whether',
#   'phone',
#   'pocket',
#   'case'],
#  ['put',
#   'latest',
#   'o',
#   'v115g',
#   'like',
#   'slow',
#   'crawl',
#   'lock',
#   'every',
#   'while'],
#  ['recognizes', 'phone', 'storage', 'device'],
#  ['like', 'loud', 'buzzing', 'override', 'conversation', 'phone', 'you'],
#  ['buy', 'product'],
#  ['ive',
#   'bluetoooth',
#   'headset',
#   'time',
#   'still',
#   'comfortable',
#   'way',
#   'fit',
#   'ear'],
#  ['sound', 'quality', 'good', 'functionality', 'awesome'],
#  ['phone', 'thorn', 'side', 'really', 'abhor', 'it'],
#  ['recently',
#   'problem',
#   'could',
#   'stay',
#   'connected',
#   '10',
#   'minute',
#   'disconnected'],
#  ['incredible'],
#  ['design', 'flaw'],
#  ['great', 'phone'],
#  ['waste', '13', 'buck'],
#  ['check',
#   'voice',
#   'mail',
#   'night',
#   'keypad',
#   'backlight',
#   'turn',
#   'second',
#   'first',
#   'message',
#   'im',
#   'lost'],
#  ['replacement', 'died', 'week'],
#  ['ring', 'toneoverall', 'good', 'phone', 'buy'],
#  ['lately', 'extremely', 'nice', 'helpful', 'phone'],
#  ['problem', 'wit', 'hit', 'dropping', 'signal', 'more'],
#  ['impressed'],
#  ['light', 'weight', 'hardly', 'notice', 'there'],
#  ['love', 'thin', 'is'],
#  ['bad', 'choice'],
#  ['pleather', 'case', 'fit'],
#  ['useless', 'phone', 'simply', 'deaf'],
#  ['color',
#   'even',
#   'prettier',
#   'thought',
#   'would',
#   'be',
#   'graphic',
#   'incredibly',
#   'sharp'],
#  ['think', 'good', 'investment'],
#  ['make', 'strange', 'ticking', 'noise', 'end', 'call'],
#  ['best', 'electronics', 'available', 'fm', 'transmitter'],
#  ['battery', 'last', 'hour'],
#  ['great', 'headset', 'impressed', 'h500'],
#  ['12', 'mega', 'pixel', 'camera', 'part', 'phone', 'reasonably', 'good7'],
#  ['ive', 'nearly', '2', 'year', 'worked', 'great', 'me'],
#  ['good', 'transmit', 'audio'],
#  ['sending', 'back'],
#  ['bother',
#   'contacting',
#   'company',
#   'dollar',
#   'product',
#   'learned',
#   'lesson',
#   'bought',
#   'form',
#   'online',
#   'anyway'],
#  ['hate', 'earbugs', 'avoid', 'phone', 'mean'],
#  ['great', 'price', 'also'],
#  ['range',
#   'decent',
#   'ive',
#   'able',
#   'roam',
#   'around',
#   'house',
#   'phone',
#   'living',
#   'room',
#   'receptionsound',
#   'quality',
#   'issue'],
#  ['fast', 'service'],
#  ['would', 'highly', 'recommend', 'this'],
#  ['would', 'recommend', 'this'],
#  ['also', 'like', 'on', 'button', 'felt', 'like', 'would', 'crack', 'use'],
#  ['worst', 'phone', 'ever'],
#  ['im', 'still', 'infatuated', 'phone'],
#  ['freeze', 'frequently4'],
#  ['kind',
#   'embarrassing',
#   'use',
#   'look',
#   'mostly',
#   'embarrassing',
#   'childlike',
#   'company',
#   'is'],
#  ['simple', 'lightweight', 'great', 'fit'],
#  ['all', 'id', 'expected', 'better', 'consumer', 'experience', 'motorola'],
#  ['there',
#   'horrible',
#   'tick',
#   'sound',
#   'background',
#   'call',
#   'never',
#   'experienced',
#   'before'],
#  ['certainly', 'comfortable', 'functionality', 'decent'],
#  ['usually', 'like', 'headband', 'one', 'lightweight', 'mess', 'hair'],
#  ['im', 'bit', 'disappointed'],
#  ['phone', 'year', 'now', 'tell', 'you', 'great'],
#  ['ordered',
#   'sony',
#   'ericsson',
#   'w810i',
#   'think',
#   'worked',
#   'thats',
#   'first',
#   'used',
#   'it'],
#  ['battery', 'completely', 'useless', 'me'],
#  ['big', 'waste', 'time'],
#  ['waste', 'one'],
#  ['great', 'sound', 'service'],
#  ['really', 'pleased', 'product', 'far'],
#  ['one', 'favorite', 'purchase', 'ever'],
#  ['best', 'bluetooth', 'market'],
#  ['authentic',
#   'leather',
#   'nice',
#   'shine',
#   'comfort',
#   'i',
#   'recommend',
#   'case'],
#  ['excited', 'get', 'headset', 'thought', 'really', 'cute'],
#  ['make', 'mistake', 'me'],
#  ['big', 'disappointment', 'calendar', 'sync'],
#  ['phone', 'unusable', 'new'],
#  ['worst', 'customer', 'service', 'ever'],
#  ['additional', 'ear', 'gel', 'provided', 'instruction', 'whatsoever'],
#  ['defeat', 'purpose', 'bluetooth', 'headset'],
#  ['worth', 'every', 'penny'],
#  ['excellent', 'wallet', 'type', 'phone', 'case'],
#  ['nice', 'headphone', 'price', 'work', 'great'],
#  ['internet', 'excrutiatingly', 'slow'],
#  ['comfortable',
#   'wear',
#   'well',
#   'probably',
#   'important',
#   'aspect',
#   'using',
#   'case'],
#  ['fit', 'like', 'glove', 'strong', 'secure', 'durable'],
#  ['gosh', 'best', 'phone', 'ever', 'had'],
#  ['attractive', 'appears', 'good', 'quality'],
#  ['love', 'feature', 'form', 'factor'],
#  ['product',
#   'strong',
#   'rubberpetroleum',
#   'smell',
#   'unbearable',
#   'caused',
#   'return'],
#  ['poor', 'quality', 'service'],
#  ['cable', 'look', 'thin', 'flimsy', 'scary'],
#  ['great', 'earpiece'],
#  ['excellent', 'hand', 'free', 'tool'],
#  ['great', 'using', 'home', 'stereo'],
#  ['good', 'product', 'incredible', 'value'],
#  ['month', 'worked', 'flawlessly', 'far'],
#  ['work', 'great'],
#  ['absolutel', 'junk'],
#  ['one', 'work', 'either'],
#  ['battery', 'life', 'real', 'good'],
#  ['returned', '8', 'hour', 'later'],
#  ['great', 'item'],
#  ['waste', 'money'],
#  ['love', 'headset'],
#  ['drain', 'player', 'may', 'also', 'potentially', 'fry', 'it'],
#  ['worked', 'perfectly'],
#  ['unreliable', 'im', 'giving', 'up'],
#  ['gave', '5', 'star', 'sound', 'quality'],
#  ['avoid', 'one', 'can'],
#  ['reversible', 'plug', 'work', 'great'],
#  ['wasted', 'little', 'money', 'earpiece'],
#  ['good', 'phone'],
#  ['best', 'rotating', 'feature', 'helpful'],
#  ['comfort', 'whole', 'family'],
#  ['good', 'product', 'good', 'seller'],
#  ['love', 'bluetooth'],
#  ['first', 'all', 'wear', 'well'],
#  ['impressed', 'headset', 'plantronics'],
#  ['got', 'small', 'adorable'],
#  ['great', 'phone'],
#  ['recommend', 'buying', 'product'],
#  ['piece', 'junk'],
#  ['poorly', 'contstruct', 'hinge'],
#  ['item',
#   'great',
#   'installed',
#   'it',
#   'let',
#   'charged',
#   'overnite',
#   'working',
#   'good',
#   'every',
#   'since',
#   'problem'],
#  ['great', 'phone'],
#  ['buy', 'it'],
#  ['excellent', 'phone'],
#  ['purchase', 'phone'],
#  ['voice', 'recognition', 'thru', 'handset', 'excellent'],
#  ['hand', 'best', 'phone', 'ive', 'ever', 'had'],
#  ['work',
#   'great',
#   'cat',
#   'attacked',
#   'phone',
#   'scratched',
#   'protective',
#   'strip',
#   'instead',
#   'destroying',
#   'screen'],
#  ['one', 'work', 'priced', 'right'],
#  ['customer', 'service', 'terrible'],
#  ['battery', 'life', 'still', 'long', 'enough', 'motorola', 'razor', 'v3i'],
#  ['sending', 'back'],
#  ['know', 'made', 'wise', 'decision'],
#  ['someone', 'shouldve', 'invented', 'sooner'],
#  ['good', 'price'],
#  ['everything',
#   'worked',
#   'first',
#   'trythe',
#   'device',
#   'certainly',
#   'engineered',
#   'clever',
#   'way',
#   'construction',
#   'feel',
#   'good'],
#  ['received', 'quickly', 'work', 'great'],
#  ['working', 'great'],
#  ['many', 'people', 'complained', 'found', 'headset', 'microphone', 'weak'],
#  ['5year',
#   'old',
#   'nokia',
#   '2160',
#   'tracfone',
#   'hold',
#   'charge',
#   'lot',
#   'better',
#   'this'],
#  ['care', 'consumer', 'one', 'bit'],
#  ['good', 'battery', 'got', 'really', 'fast'],
#  ['instruction', 'manual', 'lacking'],
#  ['also',
#   'slim',
#   'enough',
#   'fit',
#   'alarm',
#   'clock',
#   'docking',
#   'station',
#   'without',
#   'removing',
#   'case'],
#  ['phone', 'hold', 'charge', 'like', 'new'],
#  ['battery', 'unreliable', 'well', 'service', 'use', 'antena'],
#  ['uncomfortable',
#   'sound',
#   'quality',
#   'quite',
#   'poor',
#   'compared',
#   'phone',
#   'razr',
#   'previous',
#   'wired',
#   'headset',
#   'that',
#   'plugged',
#   'lg'],
#  ['gotten', 'lot', 'compliment', 'it'],
#  ['definitely', 'must', 'state', 'allow', 'cell', 'phone', 'usage', 'driving'],
#  ['want', 'money', 'back'],
#  ['love', 'device'],
#  ['also', 'happy', 'price'],
#  ['ordered', 'product', 'first', 'unhappy', 'immediately'],
#  ['ngage', 'still', 'lacking', 'earbuds'],
#  ['able', 'voice', 'dialing', 'car', 'problem'],
#  ['23', 'bar', 'cell', 'phone', 'home', 'cant', 'hear', 'anything'],
#  ['good', 'item', 'low', 'price'],
#  ['howeverthe', 'riingtones', 'best', 'neither', 'game'],
#  ['plug', 'work', 'well'],
#  ['amazon', 'suck'],
#  ['rip', 'off', 'charge', 'shipping'],
#  ['comfortable'],
#  ['battery',
#   'working',
#   'well',
#   'replacement',
#   'original',
#   'came',
#   'phone',
#   '2',
#   'year',
#   'ago'],
#  ['reception', 'excellent'],
#  ['fit',
#   'comfortably',
#   'either',
#   'ear',
#   'sound',
#   'clear',
#   'loud',
#   'charge',
#   'last',
#   'couple',
#   'day'],
#  ['clear',
#   'quality',
#   'sound',
#   'mess',
#   'sound',
#   'ipod',
#   'since',
#   'sound',
#   'button',
#   'headset'],
#  ['1',
#   'long',
#   'lasting',
#   'battery',
#   'you',
#   'recharge',
#   'frequentyly',
#   'flip',
#   'phones2'],
#  ['obviously', 'problem', 'adhesive'],
#  ['disappointing'],
#  ['inexpensive', 'piece', 'would', 'still', 'expected', 'better', 'quality'],
#  ['practically',
#   'useless',
#   'add',
#   'kind',
#   'boost',
#   'reception',
#   'bought',
#   'it'],
#  ['excellent', 'sound', 'quality'],
#  ['happy'],
#  ['piece', 'junk', 'broke', 'phone', '2', 'day'],
#  ['new', 'battery', 'work', 'great', 'phone'],
#  ['worst', 'customer', 'service'],
#  ['ive',
#   'dropped',
#   'phone',
#   'time',
#   'say',
#   'even',
#   'concrete',
#   'phone',
#   'still',
#   'great',
#   'knock',
#   'wood'],
#  ['reception', 'terrible', 'full', 'static'],
#  ['good', 'audio', 'quality'],
#  ['little',
#   'device',
#   'transformed',
#   'organizational',
#   'capability',
#   'made',
#   'life',
#   'whole',
#   'lot',
#   'easier'],
#  ['sitting', 'vehicle', 'cradle', 'belt', 'headset', 'lost', 'signal'],
#  ['jerk', 'phone'],
#  ['work', 'like', 'charm', 'work', 'advertised'],
#  ['comfortable', 'nice', 'range', 'good', 'battery', 'life'],
#  ['network', 'coverage', 'los', 'angeles', 'horrible'],
#  ['excellent', 'starter', 'wireless', 'headset'],
#  ['loudspeaker', 'option', 'great', 'bumper', 'light', 'appealing'],
#  ['thing', 'think', 'could', 'improve', 'sound', 'leak', 'headset'],
#  ['first', 'reception', 'suck', 'never', '2', 'bar', 'ever'],
#  ['phone', 'get', 'extremely', 'hot'],
#  ['microphone',
#   'also',
#   'work',
#   'well',
#   'according',
#   'people',
#   'called',
#   'applifies',
#   'everything'],
#  ['nice', 'design', 'quality'],
#  ['also',
#   'phone',
#   'dropped',
#   'case',
#   'going',
#   'save',
#   'it',
#   'specially',
#   'dropped',
#   'face',
#   'down'],
#  ['light', 'easy', 'use', 'clear', 'reception', 'transmission'],
#  ['bad', 'fit', 'way', 'big'],
#  ['definitely', 'good', 's11'],
#  ['awesome', 'device'],
#  ['waste', 'money'],
#  ['ordered',
#   'motorola',
#   'data',
#   'cable',
#   'got',
#   'well',
#   'finished',
#   'working',
#   'product'],
#  ['love', 'phone'],
#  ['looking', 'headset', 'long', 'time', 'ive', 'got', 'happier'],
#  ['ill', 'drivng', 'along', 'headset', 'start', 'ringing', 'reason'],
#  ['display', 'excellent', 'camera', 'good', 'year'],
#  ['battery', 'life', 'also', 'great'],
#  ['worst', 'phone', 'ive', 'ever', 'had', 'month'],
#  ['good',
#   'item',
#   'worked',
#   'started',
#   'problem',
#   'auto',
#   'reverse',
#   'tape',
#   'player'],
#  ['embarassing', 'also', 'ear', 'hurt', 'try', 'push', 'ear', 'plug', 'ear'],
#  ['protects', 'phone', 'side'],
#  ['average', 'phone', 'bad', 'battery', 'life', 'operates', 'weak', 'network'],
#  ['clear', 'skype', 'call', 'long', 'battery', 'life', 'long', 'range'],
#  ['soyo', 'technology', 'suck'],
#  ['great', 'hand', 'free', 'device'],
#  ['even',
#   'take',
#   'self',
#   'portrait',
#   'outside',
#   'exterior',
#   'display',
#   'cool'],
#  ['problem', 'others', 'mentioned'],
#  ['trying',
#   'many',
#   'many',
#   'handsfree',
#   'gadget',
#   'one',
#   'finally',
#   'work',
#   'well'],
#  ['magical', 'help'],
#  ['worst', 'piece', 'crap', 'ever', 'along', 'verizon', 'customer', 'service'],
#  ['poor', 'sound', 'quality'],
#  ['best', 'phone', 'market'],
#  ['worked', 'well'],
#  ['company', 'shipped', 'product', 'promptly', 'work', 'well'],
#  ['exactly', 'wanted'],
#  ['picture',
#   'resolution',
#   'far',
#   'comparablypriced',
#   'phone',
#   'offering',
#   'today'],
#  ['great', 'deal'],
#  ['excellent', 'product', 'satisfied', 'purchase'],
#  ['highly', 'recommend', 'encourage', 'people', 'give', 'try'],
#  ['better', 'expect'],
#  ['using', 'earpiece', 'left', 'right', 'thing', 'stay', 'ear'],
#  ['great', 'product', 'price'],
#  ['sound', 'good', 'reasonably', 'priced', 'effective', 'simple'],
#  ['still',
#   'waiting',
#   'im',
#   'sure',
#   'item',
#   'would',
#   'work',
#   'well',
#   'ever',
#   'recieve',
#   'it'],
#  ['disappointment'],
#  ['prompt', 'service'],
#  ['excellent', 'product', 'price'],
#  ['pleased', 'headset'],
#  ['waste', 'money', 'time'],
#  ['especially', 'love', 'long', 'battery', 'life'],
#  ['stupid',
#   'keep',
#   'buying',
#   'new',
#   'charger',
#   'car',
#   'charger',
#   'cradle',
#   'headphone',
#   'car',
#   'kit',
#   'every',
#   'time',
#   'new',
#   'phone',
#   'come',
#   'out'],
#  ['work', 'great'],
#  ['plantronics', 'bluetooth', 'excelent', 'buy'],
#  ['came',
#   'verizon',
#   'cingulair',
#   'nicer',
#   'cell',
#   'phone',
#   'first',
#   'thing',
#   'noticed',
#   'really',
#   'bad',
#   'service'],
#  ['ill', 'looking', 'new', 'earpiece'],
#  ['highly', 'recommend', 'device', 'everyone'],
#  ['jawbone', 'era', 'awesome', 'too'],
#  ['received',
#   'white',
#   'colored',
#   'battery',
#   'go',
#   'dead',
#   'couple',
#   'hoursthe',
#   'original',
#   'used',
#   'last',
#   'week',
#   'still',
#   'last',
#   'longer',
#   'thereplacement'],
#  ['year', 'battery', 'went', 'completely', 'dead', 'headset'],
#  ['used', 'several', 'phone', 'two', 'year', 'one', 'best'],
#  ['awesome', 'new', 'look', 'fall', '2000'],
#  ['first', 'phone', 'ive', 'cheaply', 'made'],
#  ['att', 'clear', 'sound', 'distorted', 'yell', 'talk'],
#  ['plastic', 'break', 'really', 'easy', 'clip'],
#  ['price', 'good', 'too'],
#  ['make', 'mistake', 'did'],
#  ['oh', 'forgot', 'also', 'mention', 'weird', 'color', 'effect', 'phone'],
#  ['im', 'using', 'iriver', 'spinn', 'with', 'case', 'fit', 'fine'],
#  ['also', 'area', 'unit', 'broke', 'im', 'fond', 'magnetic', 'strap'],
#  ['overall',
#   'psyched',
#   'phone',
#   'appointment',
#   'contact',
#   'get',
#   'great',
#   'reception'],
#  ['every', 'thing', 'phone', 'work', 'perfectly', 'like', 'it'],
#  ['another',
#   'note',
#   'phone',
#   'appearance',
#   'really',
#   'look',
#   'rather',
#   'bland',
#   'especially',
#   'black',
#   'model'],
#  ['really', 'easy'],
#  ['sanyo',
#   'survived',
#   'dozen',
#   'drop',
#   'blacktop',
#   'without',
#   'ill',
#   'effect'],
#  ['fantastic', 'earphone'],
#  ['find', 'cell', 'phone', 'right', 'away', 'enter', 'car'],
#  ['low', 'quality'],
#  ['highly', 'recommend', 'modest', 'priced', 'cellular', 'phone'],
#  ['get', 'better', 'reception', 'clarity', 'phone', 'ive', 'before'],
#  ['warning', 'stay', 'away'],
#  ['wish', 'could', 'return', 'unit', 'get', 'back', 'money'],
#  ['awsome', 'device', 'work', 'great'],
#  ['used',
#   'talk',
#   '1',
#   '1',
#   '12',
#   'hour',
#   'battery',
#   'would',
#   'literally',
#   'drained',
#   'dying'],
#  ['find',
#   'it',
#   'bad',
#   'unit',
#   'come',
#   'one',
#   'earpad',
#   'onlyi',
#   'would',
#   'recommend',
#   'anyone'],
#  ['displeased'],
#  ['might',
#   'gotten',
#   'defect',
#   'would',
#   'risk',
#   'buying',
#   'built',
#   'quality',
#   'alone'],
#  ['made', 'case', 'small', 'difficult', 'install'],
#  ['restored', 'phone', 'like', 'new', 'performance'],
#  ['would',
#   'recommend',
#   'purchasing',
#   'jabra',
#   'jx10',
#   'series',
#   '2',
#   'work',
#   'flawlessly',
#   'moto',
#   'q',
#   'go',
#   'figure'],
#  ['searched', 'internet', 'found', 'one', 'best', 'value'],
#  ['fit'],
#  ['happy', 'product'],
#  ['screen',
#   'size',
#   'big',
#   'key',
#   'pad',
#   'lit',
#   'well',
#   'enough',
#   'camera',
#   'quality',
#   'excellent',
#   'camera',
#   'phone'],
#  ['there', 'really', 'nothing', 'bad', 'say', 'headset'],
#  ['im',
#   'glad',
#   'found',
#   'product',
#   'amazon',
#   'hard',
#   'find',
#   'high',
#   'priced'],
#  ['portable', 'work'],
#  ['colleague',
#   'get',
#   'great',
#   'receptiona',
#   'little',
#   'expensive',
#   'performance',
#   'great'],
#  ['even',
#   'fully',
#   'charged',
#   'went',
#   'bed',
#   'turned',
#   'blue',
#   'tooth',
#   'wifi',
#   'noticed',
#   '20',
#   'left',
#   'morning'],
#  ['ive',
#   'also',
#   'problem',
#   'phone',
#   'reading',
#   'memory',
#   'card',
#   'always',
#   'turn',
#   'again'],
#  ['good', 'wearing', 'hat', 'sunglass'],
#  ['timely', 'shipment', 'quality', 'product'],
#  ['nice', 'solid', 'keyboard'],
#  ['well', 'made', 'fit', 'surefire', 'gx2', 'perfectly'],
#  ['horrible', 'phone'],
#  ['bt50', 'battery', 'junk'],
#  ['would', 'recommend', 'others'],
#  ['cant', 'get', 'software', 'work', 'computer'],
#  ['disappointed'],
#  ['poor', 'voice', 'clarity'],
#  ['battery', 'work', 'great'],
#  ['buyer', 'remorse', 'one'],
#  ['disappointed', 'accessoryone'],
#  ['find',
#   'inexcusable',
#   'probably',
#   'returning',
#   'phone',
#   'perhaps',
#   'changing',
#   'carrier'],
#  ['look', 'great', 'strong'],
#  ['tmobile', 'service', '2', '3', 'year', 'now', 'pretty', 'happy', 'it'],
#  ['update', 'procedure', 'difficult', 'cumbersome'],
#  ['disappointment', 'hate', 'anything', 'go', 'ear'],
#  ['great', 'software', 'motorolas'],
#  ['delivery', 'time'],
#  ['easy', 'use'],
#  ['uncomfortable', 'ear', 'use', 'lg', 'vx9900', 'env'],
#  ['volume', 'switch', 'rocketed', 'unit', 'destination', 'unknown'],
#  ['hold',
#   'charge',
#   'long',
#   'time',
#   'reasonably',
#   'comfortable',
#   'longwearing',
#   'condition',
#   'quality',
#   'sound',
#   'tremendous'],
#  ['id', 'like', 'return', 'it'],
#  ['keyboard',
#   'really',
#   'worthwhile',
#   'usefulness',
#   'sturdy',
#   'enough',
#   'expect',
#   'problem'],
#  ['verizons',
#   'bill',
#   'however',
#   'difficult',
#   'understand',
#   'even',
#   'though',
#   'pricing',
#   'plan',
#   'simple'],
#  ['charging', 'overnight', 'battery', 'work', 'great'],
#  ['regret', 'it'],
#  ['love', 'phone'],
#  ['disappointment'],
#  ['user', 'friendly'],
#  ['unfortunately',
#   'ability',
#   'actually',
#   'know',
#   'receiving',
#   'call',
#   'rather',
#   'important',
#   'feature',
#   'phone',
#   'pitiful',
#   'respect'],
#  ['exchanged', 'phone', 'even', 'problem'],
#  ['result', 'phone', 'either', 'stuck', 'max', 'volume', 'mute'],
#  ['pda', 'rock'],
#  ['super',
#   'charged',
#   'use',
#   'small',
#   'hybrid',
#   'palmtopcameracellphone',
#   'excels',
#   'role'],
#  ['would',
#   'definitely',
#   'recommend',
#   'jabra',
#   'bt250v',
#   'looking',
#   'comfort',
#   'clarity',
#   'great',
#   'price'],
#  ['verizon', '2', 'year', 'ago', 'really', 'liked', 'service'],
#  ['pretty', 'piece', 'junk'],
#  ['plug', 'wrong', 'size'],
#  ['work', 'described'],
#  ['save', 'money', 'ive', 'item', '11', 'month', 'now'],
#  ['bad', 'purchase'],
#  ['well', 'im', 'satisfied'],
#  ['bose', 'noise', 'cancelling', 'amazing', 'important', 'nyc', 'commuter'],
#  ['battery', 'excellent', 'bargain'],
#  ['defective', 'crap'],
#  ['would', 'given', 'star', 'able'],
#  ['wear', 'glass', 'fit', 'fine', 'them'],
#  ['sound',
#   'quality',
#   'device',
#   'unacceptableunless',
#   'really',
#   'quiet',
#   'area',
#   'almost',
#   'hear',
#   'nothing'],
#  ['would', 'recommend', 'item', 'anyone'],
#  ['holster', 'arrived', 'match', 'photo', 'ad'],
#  ['greatno', 'problem', 'all'],
#  ['earlier', 'review', 'noted', 'plug', 'charger', 'nothing', 'happens'],
#  ['frog', 'phone', 'charm', 'adorable', 'eye', 'catching'],
#  ['never',
#   'know',
#   'pushed',
#   'hard',
#   'enough',
#   'right',
#   'number',
#   'time',
#   'function',
#   'want',
#   'not'],
#  ['sound', 'clear', 'people', 'talk', 'amazed', 'quality', 'too'],
#  ['got',
#   'aluminum',
#   'case',
#   'new',
#   'palm',
#   'vx',
#   'worked',
#   'really',
#   'wellit',
#   'protected',
#   'handheld',
#   'perfectly',
#   'far'],
#  ['good', 'product', 'well', 'made'],
#  ['mobile', 'phone', 'tool', 'must', 'have'],
#  ['impressed', 'job', 'motorola', 'sturdiness', 'phone'],
#  ['received',
#   'order',
#   'well',
#   'within',
#   'shipping',
#   'timeframe',
#   'everything',
#   'good',
#   'working',
#   'order',
#   'overall',
#   'excited',
#   'source'],
#  ['phone', 'sturdy', 'waterproof'],
#  ['impressed', 'would', 'recommend', 'item', 'anyone'],
#  ['complaint',
#   'standard',
#   'sound',
#   'volume',
#   'little',
#   'low',
#   'even',
#   'turned',
#   '5of',
#   '5'],
#  ['thanks', 'amazon', 'thing', 'need', 'good', 'price'],
#  ['ended', 'sliding', 'edge', 'pant', 'back', 'pocket', 'instead'],
#  ['go', 'store', 'bought', 'new', 'nokia', 'phone', 'working', 'great'],
#  ['work', 'great'],
#  ['really', 'ugly'],
#  ['horrible', 'switch', '3', 'time'],
#  ['noise', 'shield', 'incrediable'],
#  ['real', 'improvement'],
#  ['razr', 'battery', 'good', 'buy'],
#  ['keep', 'good', 'work', 'amazon'],
#  ['refuse', 'refund', 'replace'],
#  ['unfortunately',
#   'easy',
#   'accidentally',
#   'activate',
#   'gentletouch',
#   'button',
#   'accidentally',
#   'touch',
#   'phone',
#   'face',
#   'listening'],
#  ['basically', 'threw', 'money', 'window', 'nothing'],
#  ['great', 'case', 'price'],
#  ['took',
#   'one',
#   'drop',
#   '6',
#   'inch',
#   'kitchen',
#   'counter',
#   'crackedi',
#   'impressed',
#   'laughing'],
#  ['bluetooth',
#   'range',
#   'good',
#   'day',
#   'ago',
#   'left',
#   'phone',
#   'trunk',
#   'got',
#   'call',
#   'carried',
#   'conversation',
#   'without',
#   'hitch'],
#  ['small',
#   'sleek',
#   'impressive',
#   'looking',
#   'practical',
#   'setup',
#   'ample',
#   'storage',
#   'place'],
#  ['eargels',
#   'channel',
#   'sound',
#   'directly',
#   'ear',
#   'seem',
#   'increase',
#   'sound',
#   'volume',
#   'clarity'],
#  ['none', 'new', 'one', 'ever', 'quite', 'worked', 'properly'],
#  ['glad', 'purchased', 'it'],
#  ['ive', 'missed', 'numerous', 'call', 'reason'],
#  ['perhaps', 'phone', 'defective', 'people', 'cannot', 'hear', 'use', 'this'],
#  ['buy', 'product'],
#  ['sucked', 'stuff', 'work', 'phone'],
#  ['shifting',
#   'bubbling',
#   'peeling',
#   'even',
#   'scratch',
#   'nothingi',
#   'happier',
#   'new',
#   'one',
#   'droid'],
#  ['worst',
#   'software',
#   'ever',
#   'used',
#   'could',
#   'give',
#   'zero',
#   'star',
#   'would'],
#  ['trying', 'make', 'call', 'exercise', 'frustration'],
#  ['case',
#   'flimsy',
#   'piece',
#   'plastic',
#   'front',
#   'side',
#   'protection',
#   'whatsoever'],
#  ['jabra',
#   'earset',
#   'happy',
#   'it',
#   'sound',
#   'quality',
#   'especially',
#   'outgoing',
#   'better'],
#  ['love', 'camera', 'really', 'pretty', 'good', 'quality'],
#  ['thank', 'great', 'service'],
#  ['total', 'package'],
#  ['seller', 'understanding', 'patient', 'would', 'definitely', 'buy', 'again'],
#  ['give',
#   'wirefly',
#   '1',
#   'stari',
#   'contact',
#   'cingularatt',
#   'inform',
#   'practice'],
#  ['aggravating'],
#  ['great', 'product', 'price'],
#  ['purchased', 'family', 'friend', 'enjoy', 'clarity', 'ease', 'use'],
#  ['virgin', 'wireless', 'rock', 'cheap', 'little', 'phone'],
#  ['none', 'work', 'buy', 'it'],
#  ['muddy',
#   'low',
#   'quality',
#   'sound',
#   'casing',
#   'around',
#   'wire',
#   'insert',
#   'poorly',
#   'super',
#   'glued',
#   'slid',
#   'off'],
#  ['please', 'dont', 'waste', 'money'],
#  ['all', 'im', 'quite', 'satisfied', 'purchase'],
#  ['looking',
#   'good',
#   'quality',
#   'motorola',
#   'headset',
#   'keep',
#   'looking',
#   'it'],
#  ['yet', 'plantronincs', 'continues', 'use', 'flawed', 'charger', 'design'],
#  ['disapointing', 'result'],
#  ['cumbersome', 'design'],
#  ['great',
#   'new',
#   'packaged',
#   'nice',
#   'work',
#   'good',
#   'problem',
#   'came',
#   'le',
#   'time',
#   'expected'],
#  ['great', 'product'],
#  ['piece', 'crap'],
#  ['experience',
#   'terrible',
#   'fourth',
#   'bluetooth',
#   'headset',
#   'much',
#   'comfortable',
#   'last',
#   'jabra',
#   'which',
#   'hated'],
#  ['fix', 'problem'],
#  ['worst', 'ever'],
#  ['happy'],
#  ['ive',
#   'trouble',
#   'accessing',
#   'internet',
#   'downloading',
#   'ringtones',
#   'performing',
#   'function'],
#  ['barely', 'ever', 'hear', 'constantly', 'saying', 'what'],
#  ['battery', 'life', 'highly', 'unacceptable'],
#  ['company', 'joke'],
#  ['everything', 'description', 'said', 'would'],
#  ['due', 'happening', 'every', 'call', 'forced', 'stop', 'using', 'headset'],
#  ['work',
#   'great',
#   'car',
#   'charger',
#   'especially',
#   'cannot',
#   'plug',
#   'two',
#   'adapter',
#   'time'],
#  ['verizon',
#   'tech',
#   'support',
#   'walked',
#   'procedure',
#   'none',
#   'worked',
#   'ended',
#   'hard',
#   'reset',
#   'wiping',
#   'data'],
#  ['voice', 'quality', 'signal', 'strength', 'dropped', 'call'],
#  ['play',
#   'louder',
#   'speaker',
#   'size',
#   'price',
#   'low',
#   'would',
#   'think',
#   'quality',
#   'lacking',
#   'however',
#   'not'],
#  ['better', 'expected'],
#  ['feel',
#   'poorly',
#   'constructed',
#   'menu',
#   'difficult',
#   'navigate',
#   'button',
#   'recessed',
#   'difficult',
#   'push',
#   'them'],
#  ['battery', 'holding', 'well'],
#  ['also', 'difficult', 'put', 'onid', 'recommend', 'avoiding', 'product'],
#  ['used', 'two', 'day', 'always', 'easy', 'hear', 'with'],
#  ['got',
#   'car',
#   'charger',
#   'even',
#   'week',
#   'charger',
#   'brokeni',
#   'went',
#   'plug',
#   'started',
#   'smoking'],
#  ['sprint', 'terrible', 'customer', 'service'],
#  ['linked', 'phone', 'without', 'effort'],
#  ['cool'],
#  ['easy', 'use'],
#  ['better', 'new'],
#  ['possesed', 'get', 'junk', 'idea'],
#  ['piece', 'trash'],
#  ['pretty', 'good', 'product'],
#  ['great', 'phone'],
#  ['price', 'amazon', 'excellent', 'product', 'would', 'highly', 'recommend'],
#  ['research',
#   'development',
#   'division',
#   'obviously',
#   'know',
#   'theyre',
#   'doing'],
#  ['real', 'killer', 'volume', 'course', 'breaking'],
#  ['phone', 'working', 'fine', 'now'],
#  ['happy', 'product'],
#  ['poor', 'construction'],
#  ['infuriating'],
#  ['overall', 'would', 'recommend', 'phone', 'new', 'walkman'],
#  ['sprint', 'charge', 'service'],
#  ['cheap', 'feel', 'look', 'cheap'],
#  ['fit', 'ear', 'well', 'comfortable', 'on'],
#  ['work', 'europe', 'asia'],
#  ['clipping',
#   'belt',
#   'deffinitely',
#   'make',
#   'feel',
#   'like',
#   '50',
#   'cent',
#   'upandcoming'],
#  ['like',
#   'design',
#   'look',
#   'jabra',
#   'behing',
#   'ear',
#   'headset',
#   '5020',
#   'pretty',
#   'comfortible',
#   'wear',
#   '24',
#   'hour',
#   'day',
#   'without',
#   'pain',
#   'ear'],
#  ['amazed',
#   'quick',
#   'arrival',
#   'two',
#   'original',
#   'lg',
#   'cell',
#   'phone',
#   'battery',
#   'fraction',
#   'price'],
#  ['worst',
#   'phone',
#   'samsungcrap',
#   'crappy',
#   'samsung',
#   'e715',
#   'worst',
#   'ever',
#   'seeen'],
#  ['charger', 'worked', 'week', 'completely', 'stopped', 'charging', 'phone'],
#  ['poor', 'product'],
#  ['however', 'needed', 'better', 'instruction'],
#  ['need',
#   'two',
#   'hand',
#   'operate',
#   'screenthis',
#   'software',
#   'interface',
#   'decade',
#   'old',
#   'cannot',
#   'compete',
#   'new',
#   'software',
#   'design'],
#  ['worked',
#   'well',
#   'paired',
#   'treo',
#   '700w',
#   'skype',
#   'headset',
#   'pc',
#   'using',
#   'usb',
#   'bluetooth',
#   'transceiver'],
#  ['steer',
#   'clear',
#   'product',
#   'go',
#   'genuine',
#   'palm',
#   'replacementr',
#   'pen',
#   'come',
#   'threepack'],
#  ['buy', 'buyit', 'suck'],
#  ['great', 'product', 'sure', 'beat', 'using', 'finger'],
#  ['plus', 'seriously', 'believe', 'worth', 'steep', 'price', 'point'],
#  ['case',
#   'ive',
#   'tried',
#   'normally',
#   'fall',
#   'apart',
#   'month',
#   'one',
#   'seems',
#   'long',
#   'haul'],
#  ['dissapointing', 'performance'],
#  ['make', 'mistake', 'please', 'buy', 'phone'],
#  ['phone', 'might', 'well', 'worst', 'ive', 'ever', 'brand'],
#  ['case',
#   'le',
#   'extra',
#   'originally',
#   'put',
#   'later',
#   'discarded',
#   'scratched',
#   'ear'],
#  ['recommend',
#   'igo',
#   'anyone',
#   'different',
#   'brand',
#   'cell',
#   'phonesmp3',
#   'player',
#   'family'],
#  ['bother', 'go', 'store'],
#  ['posted',
#   'detailed',
#   'comment',
#   'grey',
#   'black',
#   'phone',
#   'fire',
#   'red',
#   'great',
#   'color'],
#  ['problem', 'item', 'would', 'order', 'needed'],
#  ['get', 'pay', 'guess'],
#  ['software',
#   'great',
#   'job',
#   'this',
#   'could',
#   'also',
#   'make',
#   'ringtones',
#   'form',
#   'existing',
#   'cd',
#   'without',
#   'internet',
#   'connection'],
#  ['im',
#   'surprised',
#   'good',
#   'quality',
#   'car',
#   'charger',
#   'there',
#   'much',
#   'review',
#   'it'],
#  ['fabulous'],
#  ['however',
#   'bt',
#   'headset',
#   'currently',
#   'good',
#   'real',
#   'time',
#   'game',
#   'like',
#   'firstperson',
#   'shooter',
#   'since',
#   'audio',
#   'delay',
#   'mess',
#   'up'],
#  ['used',
#   'bitpim',
#   'a',
#   'free',
#   'program',
#   'find',
#   'internetto',
#   'transfer',
#   'data',
#   'phonethe',
#   'price',
#   'cable',
#   'excellent'],
#  ['disappointing', 'accessory', 'good', 'manufacturer'],
#  ['performed',
#   'awful',
#   'muffled',
#   'tinny',
#   'incoming',
#   'sound',
#   'severe',
#   'echo',
#   'end',
#   'call'],
#  ['windresistant'],
#  ['obviously', 'terrible', 'customer', 'service', 'get', 'pay', 'for'],
#  ['last',
#   'forever',
#   'overly',
#   'expensive',
#   'replaceeasy',
#   'operate',
#   'sound',
#   'much',
#   'better',
#   'others',
#   'tried'],
#  ['contacted',
#   'company',
#   'told',
#   'that',
#   'although',
#   'unit',
#   'still',
#   'warranty',
#   'produce',
#   'receipt',
#   'luck'],
#  ['linksys', 'way', 'exchange', 'bad', 'phone', 'refurb', 'unit', 'something'],
#  ['phone', 'sturdy', 'nokia', 'bar', 'phone', 'are'],
#  ['great', 'phone'],
#  ['placed', 'treo', 'case', 'snug', 'lot', 'extra', 'room', 'side'],
#  ['im', 'pleased'],
#  ['battery', 'terrible'],
#  ['found', 'product', 'easy', 'set', 'use'],
#  ['earpiece', 'large', 'heavyit', 'keep', 'falling', 'ear'],
#  ['utter', 'crap', 'sound', 'quality', 'terrible'],
#  ['charger', 'arrived', 'within', 'promised', 'timeframe', 'work'],
#  ['ear', 'loop', 'needed', 'tiny', 'sound', 'great'],
#  ['finally',
#   'three',
#   'four',
#   'time',
#   'spring',
#   'latch',
#   'broke',
#   'could',
#   'use',
#   'longer',
#   'visor'],
#  ['handsfree',
#   'part',
#   'work',
#   'fine',
#   'car',
#   'try',
#   'download',
#   'address',
#   'book',
#   'treo',
#   'rebootsoverall',
#   'still',
#   'rate',
#   'device',
#   'high'],
#  ['talk', 'useless', 'customer', 'service'],
#  ['felt', 'light', 'tinny'],
#  ['fit',
#   'palm',
#   'tungsten',
#   'e2',
#   'broke',
#   'first',
#   'time',
#   'tried',
#   'plug',
#   'in'],
#  ['im', 'happy', 'purchase', 'good', 'quality', 'low', 'price'],
#  ['love', 'look', 'feel', 'samsung', 'flipphones'],
#  ['welldesigned', 'sharp', 'blue', 'nice', 'color'],
#  ['everything', 'more'],
#  ['could', 'recommend', 'more'],
#  ['nice', 'sound'],
#  ['look', 'good', 'picture', 'case', 'huge', 'disappointment'],
#  ['much', 'le', 'jawbone', 'going', 'replace', 'with'],
#  ['setup', 'went', 'smoothly'],
#  ['extremely', 'slow', 'take', 'forever', 'anything', 'it'],
#  ['must',
#   'study',
#   'anyone',
#   'interested',
#   'worst',
#   'sin',
#   'industrial',
#   'design'],
#  ['first', 'thing', 'happened', 'tracking', 'off'],
#  ['well',
#   'made',
#   'easy',
#   'access',
#   'phone',
#   'handy',
#   'detachable',
#   'belt',
#   'clip'],
#  ['continue',
#   'pairing',
#   'periodically',
#   'since',
#   'somehow',
#   'kept',
#   'dropping'],
#  ['cant', 'upload', 'ringtones', 'third', 'party'],
#  ['bluetooth',
#   'work',
#   'phone',
#   'lock',
#   'up',
#   'screen',
#   'flash',
#   'make',
#   'call',
#   'randomly',
#   'pocket',
#   'locked'],
#  ['truly', 'awful'],
#  ['work',
#   'fine',
#   'motorola',
#   '325',
#   'cellphone',
#   'lot',
#   'better',
#   'wornout',
#   'battery',
#   'did'],
#  ['volume', 'ringer', 'real', 'good', 'you', 'choice', 'loud'],
#  ['none', 'tone', 'acceptable'],
#  ['camera', 'color', 'balance', 'awful'],
#  ['product',
#   'clearly',
#   'ready',
#   'prime',
#   'time',
#   'care',
#   'cool',
#   'look',
#   'cant',
#   'tell',
#   'call',
#   'coming',
#   'worthless'],
#  ['love', 'ringtones', 'upbeat'],
#  ['chinese', 'forgery', 'abound'],
#  ['easy', 'pair', 'samsung', 'cell'],
#  ['instruction', 'explain', 'microphone', 'jack', 'could', 'used'],
#  ['would', 'advise', 'purchase', 'item', 'never', 'worked', 'well'],
#  ['bad', 'pay', 'month', 'service'],
#  ['work', 'well'],
#  ['nokia', 'ca42', 'usb', 'cable', 'work', 'phone'],
#  ['clear', 'crisp', 'sound'],
#  ['use', 'smallest', 'earpiece', 'provided', 'stay', 'pretty', 'well'],
#  ['biggest', 'complaint', 'is', 'battery', 'drain', 'superfast'],
#  ['design', 'might', 'ergonomic', 'theory', 'could', 'stand', 'ear'],
#  ['buy', 'want', 'use', 'holster'],
#  ['phone', 'also', 'take', 'great', 'picture', 'even', 'video', 'clip'],
#  ['make', 'look', 'cool'],
#  ['ear', 'occupied', 'background', 'distracting', 'all'],
#  ['comfortable',
#   'fit',
#   'need',
#   'headset',
#   'comfortable',
#   'least',
#   'hour',
#   'time',
#   'entire',
#   'day'],
#  ['also',
#   'phone',
#   'seem',
#   'accept',
#   'anything',
#   'except',
#   'cbr',
#   'mp3s',
#   'preferably',
#   'ripped',
#   'window',
#   'medium',
#   'player'],
#  ['cant', 'beat', 'price', 'these'],
#  ['come',
#   'strong',
#   'light',
#   'use',
#   'light',
#   'camera',
#   'shot',
#   'even',
#   'flash',
#   'so',
#   'signal',
#   'seriously'],
#  ['lightweight', 'work', 'well'],
#  ['beware'],
#  ['love', 'cable', 'allows', 'connect', 'miniusb', 'device', 'pc'],
#  ['anyone', 'near', 'hear', 'part', 'conversation'],
#  ['cool', 'case', 'open', 'allowing', 'screen', 'get', 'scratched', 'up'],
#  ['bought', 'phone', 'replacement', 'startac', 'regretted', 'since'],
#  ['appears',
#   'actually',
#   'outperform',
#   'original',
#   'battery',
#   'china',
#   'came',
#   'v325i'],
#  ['cant', 'store', 'anything', 'phone', 'number', 'sim'],
#  ['last',
#   'le',
#   '3o',
#   'minute',
#   'actually',
#   'try',
#   'use',
#   'phonemy',
#   'wife',
#   'phone',
#   'problem'],
#  ['poor', 'quality'],
#  ['jabra', 'ear', 'gel', 'r', 'best'],
#  ['worth', 'it'],
#  ['phone', 'crashed', 'completely', 'get', 'replaced'],
#  ['quit',
#   'working',
#   'id',
#   'used',
#   '18',
#   'month',
#   'purchased',
#   'another',
#   'one',
#   'best',
#   'headset',
#   'ive',
#   'ever',
#   'owned'],
#  ['unfortunately',
#   'recharge',
#   'iphone',
#   '4',
#   'despite',
#   'connecting',
#   'multiple',
#   'power',
#   'source',
#   'imac',
#   'external',
#   'battery',
#   'wall',
#   'outlet',
#   'etc'],
#  ['great', 'phone'],
#  ['simply',
#   'want',
#   'small',
#   'flip',
#   'phone',
#   'look',
#   'elsewhere',
#   'extra',
#   'bell',
#   'whistle',
#   'mediocre'],
#  ['good',
#   'value',
#   'work',
#   'fine',
#   'power',
#   'via',
#   'usb',
#   'car',
#   'wall',
#   'outlet'],
#  ['phone',
#   'slide',
#   'around',
#   'car',
#   'grip',
#   'prevents',
#   'phone',
#   'slipping',
#   'hand'],
#  ['simply', 'best', 'bluetooth', 'headset', 'sound', 'quality'],
#  ['think', 'plan', 'onethis', 'sure', 'last', 'moto', 'phone', 'me'],
#  ['span', 'hour', 'two', 'people', 'exclaim', 'whoa', 'new', 'phone', 'tv'],
#  ['always', 'used', 'corded', 'headset', 'freedom', 'wireless', 'helpful'],
#  ['case',
#   'passed',
#   'one',
#   'year',
#   'mark',
#   'show',
#   'sign',
#   'wear',
#   '100',
#   'functional'],
#  ['that',
#   'leather',
#   'nice',
#   'soft',
#   'fit',
#   'tight',
#   'cut',
#   'face',
#   'good',
#   'shape'],
#  ['everything', 'need', 'ask', 'more'],
#  ['receiving', 'using', 'product', '2', 'day', 'broke'],
#  ['product',
#   'great',
#   'make',
#   'working',
#   'lot',
#   'easier',
#   'go',
#   'copier',
#   'waiting',
#   'hold',
#   'something'],
#  ['none', 'three', 'size', 'sent', 'headset', 'would', 'stay', 'ear'],
#  ['tmobile', 'best', 'customer', 'service', 'anywhere'],
#  ['arrived', 'quickly', 'much', 'le', 'expensive', 'others', 'sold'],
#  ['tried', '2', 'unit', 'failed', 'within', '2', 'month', 'pro'],
#  ['provides', 'good', 'protection', 'look', 'classy', 'too'],
#  ['krussel', 'always', 'good'],
#  ['tracfonewebsite', 'user', 'friendly', 'make', 'easy', 'toactivate', 'etc'],
#  ['design', 'good4'],
#  ['great', 'reception', 'time'],
#  ['would', 'highly', 'recommend', 'product'],
#  ['use', 'unit', 'sunglass', 'good', 'texas'],
#  ['dit', 'work', 'time', 'nokia', '5320'],
#  ['bought', 'mainly', 'charger', 'broke', 'soon', 'purchasing'],
#  ['like', 'loud', 'buzzing', 'override', 'conversation', 'phone', 'you'],
#  ['fantastic', 'buy', 'get', 'whatever', 'next', 'phone'],
#  ['stay', 'away', 'store', 'careful'],
#  ['blueant', 'supertooth', 'handsfree', 'phone', 'speaker', 'awesome'],
#  ['fit'],
#  ['item',
#   'arrived',
#   'quickly',
#   'work',
#   'great',
#   'metro',
#   'pc',
#   'samsung',
#   'schr450',
#   'slider',
#   'phone',
#   'sony',
#   'premium',
#   'sound',
#   'ear',
#   'plug'],
#  ['light',
#   'plenty',
#   'battery',
#   'capacity',
#   'confortable',
#   'wear',
#   'somewhat',
#   'extended',
#   'period',
#   'time'],
#  ['disappointing'],
#  ['blue', 'ant', 'easy', 'use'],
#  ['cheap',
#   'hey',
#   'work',
#   'pleasantly',
#   'suprised',
#   'given',
#   'low',
#   'cost',
#   'item'],
#  ['camera',
#   'phone',
#   'may',
#   'used',
#   'dustpan',
#   'indoors',
#   'id',
#   'rather',
#   'using',
#   'disposable',
#   'this'],
#  ['day', 'later', 'puff', 'smoke', 'came', 'phone', 'use'],
#  ['convenient',
#   'simple',
#   'use',
#   'get',
#   'job',
#   'done',
#   'make',
#   'car',
#   'ride',
#   'much',
#   'smoother'],
#  ['nano', 'stated', 'itmy', 'son', 'dissapointed'],
#  ['sound', 'quality', 'excellent', 'well'],
#  ['best', 'headset', 'used'],
#  ['would', 'reccommend'],
#  ['around',
#   'year',
#   'carry',
#   'highest',
#   'quality',
#   'antiglare',
#   'screen',
#   'protector',
#   'found',
#   'date'],
#  ['wanted'],
#  ['particular', 'model', 'would', 'work', 'motorola', 'q', 'smartphone'],
#  ['wont', 'work', 'right', 'atleast', 'me'],
#  ['addition',
#   'feel',
#   'amp',
#   'look',
#   'phone',
#   'lightweight',
#   'cheap',
#   'plastic'],
#  ['out',
#   'warranty',
#   'problem',
#   'reoccurebottom',
#   'line',
#   'put',
#   'money',
#   'somewhere',
#   'else',
#   'cingular',
#   'support',
#   'it'],
#  ['really',
#   'wanted',
#   'plantronics',
#   '510',
#   'right',
#   'one',
#   'many',
#   'issue',
#   'methe',
#   'good'],
#  ['great', 'product'],
#  ['crisp', 'clear'],
#  ['first', 'charge', 'kept', 'going', 'dead', '12', 'minute'],
#  ['cheap', 'plastic', 'creak', 'like', 'old', 'wooden', 'floor'],
#  ['get',
#   'absolutely',
#   'horrible',
#   'reception',
#   'apartment',
#   'phone',
#   'problem'],
#  ['reception', 'generally', 'good'],
#  ['excellent', 'sound', 'battery', 'life', 'inconspicuous', 'boot'],
#  ['great', 'bluetooth'],
#  ['highly', 'recommend', 'case'],
#  ['worthwhile'],
#  ['great', 'deal'],
#  ['phone',
#   'got',
#   'year',
#   'old',
#   'slowly',
#   'breaking',
#   'despite',
#   'much',
#   'care',
#   'part'],
#  ['sorry', 'made', 'purchase'],
#  ['bought',
#   'hoping',
#   'could',
#   'make',
#   'bluetooth',
#   'headset',
#   'fit',
#   'better',
#   'thing',
#   'made',
#   'impossible',
#   'wear'],
#  ['treo',
#   'tmobile',
#   'refused',
#   'replace',
#   'forced',
#   'buy',
#   'another',
#   'phone',
#   'without',
#   'kind',
#   'upgrade',
#   'discount'],
#  ['horrible'],
#  ['think', 'would', 'hold', 'securly', 'belt'],
#  ['allows', 'possibility', 'double', 'booking', 'date', 'time', 'first'],
#  ['work', '2', 'week', 'break'],
#  ['simple', 'use', 'like', 'it'],
#  ['great',
#   'tool',
#   'entertainment',
#   'communication',
#   'data',
#   'managementoh',
#   'sure',
#   'use',
#   'activesync',
#   '42',
#   'optimal',
#   'data',
#   'synchronization',
#   'result'],
#  ['cant', 'use', 'case', 'smell', 'disgusting'],
#  ['wanted'],
#  ['2', 'case', 'would', 'order', 'another'],
#  ['great', 'phone'],
#  ['bought', 'battery', 'coupon', 'amazon', 'im', 'happy', 'purchase'],
#  ['internet', 'access', 'fine', 'rare', 'instance', 'worked'],
#  ['perfect', 'ps3'],
#  ['five', 'star', 'plus', 'plus'],
#  ['good',
#   'quality',
#   'bargain',
#   'bought',
#   'bought',
#   'cheapy',
#   'big',
#   'lot',
#   'sounded',
#   'awful',
#   'people',
#   'end',
#   'hear',
#   'me'],
#  ['50', 'drain'],
#  ['tried',
#   'talking',
#   'real',
#   'loud',
#   'shouting',
#   'telephone',
#   'get',
#   'old',
#   'still',
#   'told',
#   'great'],
#  ['good', 'work', 'fine'],
#  ['price', 'great', 'deal'],
#  ['great', 'price', 'too'],
#  ['wind', 'completely', 'useless'],
#  ['yes', 'shiny', 'front', 'side', 'love', 'it'],
#  ['work'],
#  ['first',
#   'thought',
#   'grtting',
#   'good',
#   'deal',
#   '744',
#   'plugged',
#   'phone',
#   'v3c',
#   'razr'],
#  ['reception', 'headset', 'excellent'],
#  ['2', 'thumb', 'seller'],
#  ['verizon',
#   'lg',
#   'phone',
#   'work',
#   'well',
#   'together',
#   'good',
#   'reception',
#   'range',
#   'exceeds',
#   '20',
#   'foot',
#   'line',
#   'sight'],
#  ['improper', 'description', 'return', 'it'],
#  ['1', 'work', '2', 'comfortable'],
#  ['battery', 'chargelife', 'quite', 'long'],
#  ['jabra', 'eargels', 'fit', 'ear', 'well'],
#  ['battery', 'life'],
#  ['checked', 'everywhere', 'feature', 'really', 'disappointing'],
#  ['product', 'exactly', 'described'],
#  ['get', 'signal', 'verizon', 'phone', 'wont'],
#  ['job'],
#  ['would', 'recommend', 'it'],
#  ['plan', 'ordering', 'again'],
#  ['said',
#   'phone',
#   'camera',
#   'nice',
#   'many',
#   'cool',
#   'effect',
#   'play',
#   'with',
#   'video',
#   'decent',
#   'well'],
#  ['satisfied', 'cell', 'phone', 'day', 'one'],
#  ['keep',
#   'getting',
#   'better',
#   'better',
#   'this',
#   'third',
#   'one',
#   'ive',
#   'numerous',
#   'palm',
#   'too'],
#  ['awkward', 'use', 'unreliable'],
#  ['shipping', 'time', 'also', 'quick'],
#  ['good', 'hoped'],
#  ['good', 'case'],
#  ['work'],
#  ['really', 'good', 'product'],
#  ['unfortunately', 'work'],
#  ['three', 'broke', 'within', 'two', 'month', 'use'],
#  ['dont', 'buy', 'it'],
#  ['father', 'v265', 'battery', 'dying'],
#  ['however', 'ear', 'pad', 'come', 'easily', 'one', 'week', 'lost', 'one'],
#  ['call',
#   'drop',
#   'phone',
#   'come',
#   'will',
#   'screen',
#   'go',
#   'black',
#   'worst',
#   'stop',
#   'ringing',
#   'intermittently'],
#  ['horrible', 'horrible', 'protector'],
#  ['like', 'nokia', 'either'],
#  ['reaching',
#   'bottom',
#   'row',
#   'uncomfortable',
#   'send',
#   'end',
#   'key',
#   'expect',
#   'be3'],
#  ['bought', 'nokia', 'cell', 'phone', 'week', 'ago', 'nightmare'],
#  ['would',
#   'take',
#   'long',
#   'describe',
#   'bad',
#   'customer',
#   'service',
#   'experience',
#   'amazon'],
#  ['disappointing', 'thing', 'speakerphone'],
#  ['terrible', 'car', 'accept', 'cassette'],
#  ['product',
#   'useless',
#   'since',
#   'enough',
#   'charging',
#   'current',
#   'charge',
#   '2',
#   'cellphone',
#   'planning',
#   'use',
#   'with'],
#  ['say', 'is'],
#  ['stay', 'away', 'q'],
#  ['used', 'dirty'],
#  ['unreliable', 'service', 'tmobile'],
#  ['good', 'enough', 'price'],
#  ['bought', 'two', 'neither', 'charge'],
#  ['look', 'nice'],
#  ['excellent', 'tool', 'especially', 'paired', 'phone', 'autoanswer'],
#  ['read', 'others', 'review', 'problem', 'it'],
#  ['product', 'cover', 'important', 'light', 'sensor', 'ear', 'outlet'],
#  ['comfortable', 'hand'],
#  ['work'],
#  ['poor', 'reliability'],
#  ['it', 'work'],
#  ['take',
#   'picture',
#   'battery',
#   'drop',
#   'bar',
#   'start',
#   'beeping',
#   'letting',
#   'know',
#   'dieing'],
#  ['terrible', 'product', 'waste', 'money'],
#  ['last', 'time', 'buying', 'you'],
#  ['waste', 'money'],
#  ['far', 'worked', 'like', 'charm'],
#  ['week', 'far', 'good'],
#  ['but',
#   'case',
#   'best',
#   'part',
#   'is',
#   'download',
#   'picture',
#   'laptop',
#   'using',
#   'ir',
#   'even',
#   'send',
#   'picture',
#   'laptop',
#   'phone'],
#  ['would', 'recommend', 'item'],
#  ['choice',
#   'headset',
#   'yearsgreat',
#   'sound',
#   'good',
#   'volume',
#   'good',
#   'noise',
#   'cancellation'],
#  ['nice', 'case', 'feel', 'good', 'hand'],
#  ['item', 'received', 'counterfeit'],
#  ['really', 'good', 'far', 'probably', 'best', 'bt', 'headset', 'ever', 'had'],
#  ['work', 'fine'],
#  ['received', 'headset', 'good', 'time', 'happy', 'it'],
#  ['pleased',
#   'see',
#   'could',
#   'replace',
#   'well',
#   'travled',
#   'swivel',
#   'holster',
#   'blackberry',
#   'flip'],
#  ['sister', 'one', 'also', 'love', 'it'],
#  ['good', 'quality'],
#  ['far', 'worst', 'purchase', 'ive', 'made', 'amazon'],
#  ['excellent', 'dualpurpose', 'headset'],
#  ['excellent'],
#  ['work', 'listening', 'music', 'cingular', '8125'],
#  ['seems',
#   'completely',
#   'secure',
#   'holding',
#   'belt',
#   'keeping',
#   'iphone',
#   'inside'],
#  ['bottowm', 'lineanother', 'worthless', 'cheap', 'gimmick', 'sprint'],
#  ['trouble', 'volume'],
#  ['good', 'thing', 'fit', 'comfortably', 'small', 'ear'],
#  ['warning', 'buy'],
#  ['pairing', 'iphone', 'could', 'happier', 'far'],
#  ['open', 'battery', 'connection', 'broken', 'device', 'turned', 'off'],
#  ['want', 'clip', 'going', 'top', 'ear', 'causing', 'discomfort'],
#  ['best', 'headset', 'ever'],
#  ['trust', 'website', 'expect', 'helpful', 'support'],
#  ['loudglad',
#   'say',
#   'plantronics',
#   '510',
#   'maintains',
#   'flawless',
#   'connection',
#   'cell',
#   'static',
#   'normal',
#   'use'],
#  ['speaker', 'low', 'quality', 'making', 'ring', 'tone', 'sound', 'cheap'],
#  ['fit', 'comfortably', 'came', 'three', 'size', 'earbud', 'tip'],
#  ['excellent', 'product', 'price'],
#  ['bad', 'reception'],
#  ['product', 'high', 'quality', 'chinese', 'crap'],
#  ['quite', 'comfortable', 'ear'],
#  ['great', 'phone'],
#  ['buy', 'product', 'fails'],
#  ['everything', 'product', 'wrongfirst'],
#  ['pairing',
#   'two',
#   'device',
#   'easy',
#   'barely',
#   'took',
#   'couple',
#   'minute',
#   'started',
#   'making',
#   'call',
#   'voice',
#   'dialing',
#   'feature'],
#  ['utterly',
#   'confusing',
#   'first',
#   'caused',
#   'lose',
#   'couple',
#   'very',
#   'important',
#   'contact'],
#  ['terrible', 'phone', 'holder'],
#  ['cutout', 'button', 'placed', 'perfectly'],
#  ['love', 'able', 'use', 'one', 'headset', 'landline', 'cell'],
#  ['problem', 'ear', 'loop', 'made', 'weak', 'material', 'break', 'easily'],
#  ['nearly', 'good', 'looking', 'amazon', 'picture', 'make', 'look'],
#  ['despite',
#   'flaw',
#   'case',
#   'exceptional',
#   'quality',
#   'well',
#   'worth',
#   'additional',
#   'cost',
#   'owning',
#   'official',
#   'oem',
#   'product'],
#  ['stupid', 'that'],
#  ['hear',
#   'im',
#   'driving',
#   'car',
#   'usually',
#   'even',
#   'put',
#   'loudest',
#   'setting'],
#  ['seller', 'shipped', 'quickly', 'much', 'cheaper', 'competitor'],
#  ['good', 'show', 'samsung'],
#  ['bought', '10', 'saved', 'alot', 'money'],
#  ['always',
#   'cut',
#   'make',
#   'beep',
#   'beep',
#   'beep',
#   'sound',
#   'say',
#   'signal',
#   'failed'],
#  ['figure'],
#  ['phone',
#   'sounded',
#   'ok',
#   'great',
#   'ok',
#   'wife',
#   'phone',
#   'almost',
#   'totally',
#   'unintelligible',
#   'understand',
#   'word',
#   'said',
#   'it'],
#  ['take', 'battery', 'phone', 'put', 'back', 'together', 'restart', 'it'],
#  ['managed',
#   'bend',
#   'leaf',
#   'spring',
#   'back',
#   'place',
#   'metal',
#   'enough',
#   'stress',
#   'break',
#   'next',
#   'drop'],
#  ['leopard', 'print', 'wonderfully', 'wild'],
#  ['work', 'me'],
#  ['saggy', 'floppy', 'piece', 'junk'],
#  ['much', 'better', 'hard', 'plastic', 'case'],
#  ['also', 'new', 'problem'],
#  ['happy', 'far'],
#  ['cool', 'phone'],
#  ['work', 'good'],
#  ['motorola',
#   'finally',
#   'got',
#   'voice',
#   'quality',
#   'bluetooth',
#   'headset',
#   'right'],
#  ['loos', 'connection', 'phone', 'even', 'within', 'couple', 'foot', 'two'],
#  ['great', 'would', 'really', 'recommend'],
#  ['make', 'easier', 'keep', 'bluetooth', 'im', 'wearing', 'it'],
#  ['said', 'abovepretty', 'useless'],
#  ['never', 'got', 'it'],
#  ['pair', 'headphone', 'worst', 'ever', 'soundwise'],
#  ['drain', 'weak', 'snap'],
#  ['charge', 'cingular', 'att', '8525', 'phone'],
#  ['get', 'extra', 'minute', 'carry', 'call', 'get', 'cut', 'off'],
#  ['however',
#   'year',
#   'fliptop',
#   'started',
#   'get',
#   'loose',
#   'wobbly',
#   'eventually',
#   'screen',
#   'went',
#   'black',
#   'receive',
#   'place',
#   'call'],
#  ['kept', 'catching', 'cable', 'seat', 'pull', 'phone', 'turn', 'off'],
#  ['headset', 'fulfills', 'requirement', 'happy', 'purchase'],
#  ['logitech', 'bluetooth', 'headset', '10'],
#  ['like', 'fact', 'rest', 'lightly', 'ear', 'rather', 'inside'],
#  ['lot', 'website', 'rating', 'good', 'phone', 'i'],
#  ['tried', 'cable', 'computer', 'ipod', 'work', 'fine'],
#  ['mic', 'joke', 'volume', 'quite', 'low'],
#  ['im', 'returning', 'them'],
#  ['maintain', 'connection', 'computer', 'lap'],
#  ['easy', 'turn', 'car', 'volume', 'control', 'quite', 'accessable'],
#  ['mine', 'year', 'christmas', 'bought', 'rest', 'family'],
#  ['otherwise', 'easy', 'install', 'use', 'clear', 'sound'],
#  ['nice', 'leather'],
#  ['purchase', 'different', 'case'],
#  ['joy', 'use'],
#  ['much', 'disappointed', 'company'],
#  ['satisifed', 'that'],
#  ['charge', 'me'],
#  ['phone', 'get', '2005', 'bought', 's710a', 'say', 'wow'],
#  ['button', 'small'],
#  ['reading', 'spec', 'alone', 'make', 'say', 'wow'],
#  ['love', 'it', 'great', 'armband'],
#  ['really',
#   'like',
#   'product',
#   'motorola',
#   'allot',
#   'clearer',
#   'ear',
#   'piece',
#   'mic'],
#  ['however', 'keypad', 'tinny', 'sometimes', 'reach', 'wrong', 'button'],
#  ['exchanged',
#   'sony',
#   'ericson',
#   'z500a',
#   'im',
#   'pretty',
#   'happy',
#   'decision'],
#  ['impressed', 'price', 'case'],
#  ['also', 'make', 'easier', 'hold', 'to'],
#  ['use',
#   'product',
#   'motor',
#   'control',
#   'center',
#   'lot',
#   'high',
#   'voltage',
#   'humming',
#   'equipment',
#   'work',
#   'great'],
#  ['pretty', 'easy'],
#  ['cannot', 'make', 'call', 'certain', 'place'],
#  ['however',
#   'girl',
#   'complain',
#   'time',
#   'phone',
#   'wake',
#   'like',
#   'normal',
#   'phone',
#   'doe'],
#  ['beautiful', 'styling', 'though'],
#  ['company',
#   'charge',
#   'restocking',
#   'fee',
#   'still',
#   'given',
#   'refund',
#   'back'],
#  ['im', 'trying', 'return', 'refund'],
#  ['plugged', 'find', 'darn', 'thing', 'worked'],
#  ['excellent', 'product'],
#  ['earbud', 'piece', 'break', 'easily'],
#  ['lousy', 'product'],
#  ['phone', 'try', 'hard', 'everything', 'fails', 'ability', 'phone'],
#  ['best', 'charger', 'seen', 'market', 'yet'],
#  ['sweetest', 'phone'],
#  ['oh', 'charger', 'seems', 'work', 'fine'],
#  ['fit',
#   'securely',
#   'ear',
#   'hook',
#   'even',
#   'need',
#   'used',
#   'sound',
#   'better',
#   'directed',
#   'ear',
#   'canal'],
#  ['enough', 'volume'],
#  ['echo', 'problemvery', 'unsatisfactory'],
#  ['could', 'take', '2', 'video', 'time', 'quality', 'poor'],
#  ['waste', 'money'],
#  ['going', 'first', 'negatively', 'review', 'product'],
#  ['adapter', 'provide', 'enough', 'charging', 'current'],
#  ['much', 'hype', 'phone', 'assumed', 'best', 'mistake'],
#  ['also', 'cannot', 'take', 'picture', 'case', 'lense', 'covered'],
#  ['phone', 'fall', 'easily'],
#  ['work', 'people', 'hear', 'talk'],
#  ['text', 'messaging', 'feature', 'really', 'tricky', 'use'],
#  ['im', 'really', 'disappointed', 'charger', 'work'],
#  ['painful', 'ear'],
#  ['lasted', 'one', 'day', 'blew', 'up'],
#  ['disappointed'],
#  ['kind', 'flop', 'around'],
#  ['screen', 'get', 'smudged', 'easily', 'touch', 'ear', 'face'],
#  ['piece', 'junk', 'lose', 'call', 'phone'],
#  ['item', 'match', 'picture'],
#  ['thing', 'disappoint', 'infra', 'red', 'port', 'irda'],
#  ['answer', 'call', 'unit', 'never', 'worked', 'once']]

# %%
# It looks right to me. Let's put it back into the model

model_clean = Word2Vec(doc_clean, size = 100, window = 5, min_count = 5, workers = 4)

# %%
# How did it do? Let's try this function again
model_new.wv.most_similar(positive = ['great'])
# Out:
# [('makes', 0.27968427538871765),
#  ('talk', 0.27064287662506104),
#  ('works', 0.25068968534469604),
#  ('headsets', 0.24682296812534332),
#  ('purchase', 0.21913033723831177),
#  ('long', 0.18717731535434723),
#  ('gets', 0.18573476374149323),
#  ('did', 0.18376567959785461),
#  ('fits', 0.1788528561592102),
#  ('phones', 0.1679503619670868)]
